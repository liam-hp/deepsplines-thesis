# %%
from models import LinearBSpline
from utils import plot_bspline, plot_layer
import matplotlib.pyplot as plt

model = LinearBSpline([8], 3, 1, 'relu')
locs = model.get_deepspline_activations()[0]['locations'][0] # last index selects which spline from the layer
coeffs = model.get_deepspline_activations()[0]['coefficients'][0]

# %%
import utils
import importlib
import numpy as np
from scipy.interpolate import BSpline

model = LinearBSpline([8], 3, 1, 'relu')
locs = model.get_deepspline_activations()[0]['locations'][0] # last index selects which spline from the layer
coeffs = model.get_deepspline_activations()[0]['coefficients'][0]

# %%
importlib.reload(utils)

utils.plot_bspline(locs, coeffs, 1, False)
