# %% [markdown]
# ### A Notebook for the Graphs I'm presenting in the paper

# %%
import utils, importlib
# Out:
# [2025-01-12 15:48:24,937] [WARNING] [real_accelerator.py:174:get_accelerator] Setting accelerator to CPU. If you have GPU or other accelerator, we were unable to detect it.
# [2025-01-12 15:48:24,973] [INFO] [real_accelerator.py:219:get_accelerator] Setting ds_accelerator to cpu (auto detect)
# ...

# %% [markdown]
# ### Control Points

# %%
import importlib, utils
importlib.reload(utils)

selector = "med"
data = "vals"

utils.plot_seaborn(
    # title="ReLU vs BSpline, W&B_lr=0.001 BS_lr=0.0001 ctrl=3",
    model_paths=[
        # throw a relu in here - actually looks like advantage for less
        # should note on how many prev research used
        ("control points test", "[24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),
        ("control points test", "[24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100_5", "vals", f"{selector}"),
        ("control points test", "[24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100_11", "vals", f"{selector}"),
        ("control points test", "[24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100_23", "vals", f"{selector}"),
        ("control points test", "[24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100_55", "vals", f"{selector}"),
        ("control points test", "[24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100_111", "vals", f"{selector}"),
    ],
    aes=[
        ("ctrl=3", "[8]"),
        ("ctrl=5", "[8]"),
        ("ctrl=11", "[8]"),
        ("ctrl=23", "[8]"),
        ("ctrl=55", "[8]"),
        ("ctrl=111", "[8]"),
    ],
    # y_ax = "Train Loss",
    x = "epochs", 
    # xlim = 300,
    xmin = 0,
    ylim = .6,
    ymin = .4,
    hide_legend = False
    # vbars = [(149, "lightgrey"), (169, "lightgrey")],
)
# Out:
# Avg over last 5 epochs on ctrl=3,[8],med: 0.44279999999999997 in 757.9136882699995s
# Avg over last 5 epochs on ctrl=5,[8],med: 0.4396 in 797.7626864700006s
# Avg over last 5 epochs on ctrl=11,[8],med: 0.4382 in 784.94732361s
# Avg over last 5 epochs on ctrl=23,[8],med: 0.4465 in 778.4862561399997s
# Avg over last 5 epochs on ctrl=55,[8],med: 0.4545 in 777.0846192871289s
# Avg over last 5 epochs on ctrl=111,[8],med: 0.4658 in 792.821443685714s

# %% [markdown]
# ### ReLU Learning Rate

# %%
importlib.reload(utils)

arch = "[24, 48, 24, 8]"

utils.plot_multiple_3(
    title=f"ReLU Learning Rate Tuning, arch={arch}",
    model_paths=[
        (f"learning_rate/{arch}", f"{arch}_(0.005,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", "avg"),
        (f"learning_rate/{arch}", f"{arch}_(0.0025,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", "avg"),
        (f"learning_rate/{arch}", f"{arch}_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", "avg"),
        (f"learning_rate/{arch}", f"{arch}_(0.00075,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", "avg"),
        (f"learning_rate/{arch}", f"{arch}_(0.0005,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", "avg"),
        (f"learning_rate/{arch}", f"{arch}_(0.00025,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", "avg"),
        (f"learning_rate/{arch}", f"{arch}_(0.0001,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", "avg"),
        (f"learning_rate/{arch}", f"{arch}_(7.5e-05,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", "avg"),
    ],
    model_names=[
        "lr=0.005",
        "lr=0.0025",
        "lr=0.001",
        "lr=0.0075",
        "lr=0.0005",
        "lr=0.00025",
        "lr=0.0001",
        "lr=0.000075",
    ],
    x="epochs", 
    # xlim = 300,
    xmin=0,
    ylim = .8,
    ymin=.3,
    hide_legend=True
    # vbars = [(149, "lightgrey"), (169, "lightgrey")],
)

# %%
import importlib
importlib.reload(utils)

utils.plot_multiple_3(
    title="Average over 100 Runs",
    model_paths=[
        ("learning_rate/[8]", "[8]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", "avg"), 
        ("learning_rate/[24, 8]", "[24, 8]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", "avg"),
        ("learning_rate/[24, 48, 24, 8]", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", "avg"),
    ],
    model_names=[
        "ReLU: [8,8]",
        "ReLU: [8,24,8]",
        "ReLU: [8,24,48,24,8]",
    ],
    x="epochs", 
    xlim = 300,
    xmin=0,
    ylim = .8,
    ymin=.3,
    hide_legend=False
    # vbars = [(149, "lightgrey"), (169, "lightgrey")],
)

# %% [markdown]
# ### BSpline Learning Rate

# %%
importlib.reload(utils)

arch = "[24, 48, 24, 8]"

utils.plot_multiple_3(
    title=f"BSpline Learning Rate Tuning, arch={arch}, W&B_lr=0.001",
    model_paths=[
        (f"learning_rate/{arch}", f"{arch}_(0.001,0.0005,0.0001)_(0,0,200,0,0)_100", "vals", "avg"),
        (f"learning_rate/{arch}", f"{arch}_(0.001,0.00025,0.0001)_(0,0,200,0,0)_100", "vals", "avg"),
        (f"learning_rate/{arch}", f"{arch}_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", "vals", "avg"),
        (f"learning_rate/{arch}", f"{arch}_(0.001,7.5e-05,0.0001)_(0,0,200,0,0)_100", "vals", "avg"),
        (f"learning_rate/{arch}", f"{arch}_(0.001,5e-05,0.0001)_(0,0,200,0,0)_100", "vals", "avg"),
    ],
    model_names=[
        "lr=0.0005",
        "lr=0.00025",
        "lr=0.0001",
        "lr=0.000075",
        "lr=0.00005",
    ],
    x="epochs", 
    # xlim = 300,
    xmin=0,
    ylim = .7,
    ymin=.4,
    hide_legend=True
    # vbars = [(149, "lightgrey"), (169, "lightgrey")],
)

# %% [markdown]
# ### ReLU vs BSpline (same layers)

# %%
import importlib, utils
importlib.reload(utils)

selector = "med"
data = "vals"

utils.plot_seaborn(
    # title="ReLU vs BSpline, W&B_lr=0.001 BS_lr=0.0001 ctrl=3",
    model_paths=[
        ("learning_rate/[8]", "[8]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", f"{data}", f"{selector}"),
        ("learning_rate/[8]", "[8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", f"{data}", f"{selector}"),

        ("learning_rate/[24, 8]", "[24, 8]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", f"{data}", f"{selector}"),
        ("learning_rate/[24, 8]", "[24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", f"{data}", f"{selector}"),

        ("learning_rate/[24, 48, 24, 8]", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", f"{data}", f"{selector}"),
        ("learning_rate/[24, 48, 24, 8]", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", f"{data}", f"{selector}"),
    ],
    aes=[
        ("ReLU", "[8]"),
        ("BSpline", "[8]"),
        ("ReLU", "[24, 8]"),
        ("BSpline", "[24, 8]"),
        ("ReLU", "[24, 48, 24, 8]"),
        ("BSpline", "[24, 48, 24, 8]"),
    ],
    # palette=["black", "blue"],
    # y_ax = "Train Loss",
    x="epochs", 
    # xlim = 300,
    xmin=0,
    ylim = .7,
    ymin=.3,
    hide_legend=False
    # vbars = [(149, "lightgrey"), (169, "lightgrey")],
)
# Out:
# [2025-01-15 17:02:09,128] [WARNING] [real_accelerator.py:174:get_accelerator] Setting accelerator to CPU. If you have GPU or other accelerator, we were unable to detect it.
# [2025-01-15 17:02:09,164] [INFO] [real_accelerator.py:219:get_accelerator] Setting ds_accelerator to cpu (auto detect)
# ...
# Avg over last 5 epochs on ReLU,[8],med: 0.4868 in 191.56679745544545s
# Avg over last 5 epochs on BSpline,[8],med: 0.47940000000000005 in 501.10176714705887s
# Avg over last 5 epochs on ReLU,[24, 8],med: 0.4644 in 230.9543103960394s
# Avg over last 5 epochs on BSpline,[24, 8],med: 0.44394999999999996 in 779.952086647058s
# Avg over last 5 epochs on ReLU,[24, 48, 24, 8],med: 0.439 in 308.6244620666665s
# Avg over last 5 epochs on BSpline,[24, 48, 24, 8],med: 0.4335 in 1298.4482278811884s

# %% [markdown]
# ### ReLU v BSpline: Parameter Control

# %%
import importlib, utils
importlib.reload(utils)

arch="arch"
selector = "med"
data = "vals"

utils.plot_seaborn(
    # title="ReLU vs BSpline, W&B_lr=0.001 BS_lr=0.0001 ctrl=3",
    model_paths=[
        ("param control", "[11]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", f"{data}", f"{selector}"),
        ("learning_rate/[8]", "[8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", f"{data}", f"{selector}"),

        ("param control", "[30, 8]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", f"{data}", f"{selector}"),
        ("learning_rate/[24, 8]", "[24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", f"{data}", f"{selector}"),

        ("param control", "[26, 50, 26, 8]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", f"{data}", f"{selector}"),
        ("learning_rate/[24, 48, 24, 8]", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", f"{data}", f"{selector}")

        # ("param control", "[26, 50, 98, 50, 26, 8]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", f"{data}", f"{selector}"),
    ],
    aes=[
        ("ReLU", "110 Params"),
        ("BSpline", "110 Params"),
        ("ReLU", "530 Params"),
        ("BSpline", "530 Params"),
        ("ReLU", "3.1K Params"),
        ("BSpline", "3.1K Params"),
    ],
    # y_ax = "Train Loss",
    x="epochs", 
    # xlim = 300,
    xmin=0,
    ylim = .7,
    ymin=.3,
    hide_legend=False
    # vbars = [(149, "lightgrey"), (169, "lightgrey")],
)
# Out:
# Avg over last 5 epochs on ReLU,110 Params,med: 0.4929
# Avg over last 5 epochs on BSpline,110 Params,med: 0.47940000000000005
# Avg over last 5 epochs on ReLU,530 Params,med: 0.46004999999999996
# Avg over last 5 epochs on BSpline,530 Params,med: 0.44394999999999996
# Avg over last 5 epochs on ReLU,3.1K Params,med: 0.44205
# Avg over last 5 epochs on BSpline,3.1K Params,med: 0.4335

# %% [markdown]
# ### ReLU v BSpline: FLOPs Control

# %%
import importlib, utils
importlib.reload(utils)

arch="arch"
selector = "med"
data = "vals"

utils.plot_seaborn(
    # title="ReLU vs BSpline, W&B_lr=0.001 BS_lr=0.0001 ctrl=3",
    model_paths=[
        ("flops control", "[24]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", f"{data}", f"{selector}"),
        ("learning_rate/[8]", "[8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", f"{data}", f"{selector}"),

        ("flops control", "[64, 8]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", f"{data}", f"{selector}"),
        ("learning_rate/[24, 8]", "[24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", f"{data}", f"{selector}"),

        ("flops control", "[24, 96, 24, 8]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", f"{data}", f"{selector}"),
        ("learning_rate/[24, 48, 24, 8]", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", f"{data}", f"{selector}")

        # ("flops control", "[24, 48, 144, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", f"{data}", f"{selector}"),
    ],
    aes=[
        ("ReLU", "450 FLOPs"),
        ("BSpline", "450 FLOPs"),

        ("ReLU", "2k FLOPs"),
        ("BSpline", "2k FLOPs"),

        ("ReLU", "10k FLOPs"),
        ("BSpline", "10k FLOPs"),
    ],
    y_ax = "MSE Loss (Validation)",
    x="epochs", 
    # xlim = 300,
    xmin=0,
    ylim = .7,
    ymin=.3,
    hide_legend=False
    # vbars = [(149, "lightgrey"), (169, "lightgrey")],
)
# Out:
# Avg over last 5 epochs on ReLU,450 FLOPs,med: 0.4851
# Avg over last 5 epochs on BSpline,450 FLOPs,med: 0.47940000000000005
# Avg over last 5 epochs on ReLU,2k FLOPs,med: 0.4571
# Avg over last 5 epochs on BSpline,2k FLOPs,med: 0.44394999999999996
# Avg over last 5 epochs on ReLU,10k FLOPs,med: 0.4331
# Avg over last 5 epochs on BSpline,10k FLOPs,med: 0.4335

# %% [markdown]
# ### ReLU v BSpline: Latency Control

# %%
import importlib, utils
importlib.reload(utils)

arch="arch"
selector = "med"
data = "vals"

utils.plot_seaborn(
    # title="ReLU vs BSpline, W&B_lr=0.001 BS_lr=0.0001 ctrl=3",
    model_paths=[
        ("", "(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", f"{data}", f"{selector}"),
        ("learning_rate/[8]", "[8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", f"{data}", f"{selector}"),

        ("", "(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", f"{data}", f"{selector}"),
        ("", "[16, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", f"{data}", f"{selector}"),

        ("", "(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", f"{data}", f"{selector}"),
        ("", "(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", f"{data}", f"{selector}")
        
    ],
    aes=[
        ("ReLU", "450 FLOPs"),
        ("BSpline", "450 FLOPs"),

        ("ReLU", "2k FLOPs"),
        ("BSpline", "2k FLOPs"),

        ("ReLU", "10k FLOPs"),
        ("BSpline", "10k FLOPs"),
    ],
    y_ax = "MSE Loss (Validation)",
    x="epochs", 
    # xlim = 300,
    xmin=0,
    ylim = .7,
    ymin=.3,
    hide_legend=False
    # vbars = [(149, "lightgrey"), (169, "lightgrey")],
)

# %% [markdown]
# ### ReLU to WBSpline

# %% [markdown]
# Sweeping numbers of pretraining epochs

# %%
import importlib, utils
importlib.reload(utils)

# arch="[24, 48, 24, 8]"
selector = "med"
data = "vals"

utils.plot_seaborn(
    # title="ReLU vs BSpline, W&B_lr=0.001 BS_lr=0.0001 ctrl=3",
    model_paths=[
        ("R(WB) switching", f"[8]_(0.001,0.0001,0.0001)_(75,0,50,50,0)_100", f"{data}", f"{selector}"),
        ("R(WB) switching", f"[8]_(0.001,0.0001,0.0001)_(100,0,50,50,0)_100", f"{data}", f"{selector}"),
        ("R(WB) switching", f"[8]_(0.001,0.0001,0.0001)_(150,0,50,50,0)_100", f"{data}", f"{selector}"),
        ("R(WB) switching", f"[8]_(0.001,0.0001,0.0001)_(200,0,50,50,0)_100", f"{data}", f"{selector}"),

        ("R(WB) switching", f"[24, 8]_(0.001,0.0001,0.0001)_(75,0,50,50,0)_100", f"{data}", f"{selector}"),
        ("R(WB) switching", f"[24, 8]_(0.001,0.0001,0.0001)_(100,0,50,50,0)_100", f"{data}", f"{selector}"),
        ("R(WB) switching", f"[24, 8]_(0.001,0.0001,0.0001)_(150,0,50,50,0)_100", f"{data}", f"{selector}"),
        ("R(WB) switching", f"[24, 8]_(0.001,0.0001,0.0001)_(200,0,50,50,0)_100", f"{data}", f"{selector}"),

        ("R(WB) switching", f"[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(75,0,50,50,0)_100", f"{data}", f"{selector}"),
        ("R(WB) switching", f"[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(100,0,50,50,0)_100", f"{data}", f"{selector}"),
        ("R(WB) switching", f"[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(150,0,50,50,0)_100", f"{data}", f"{selector}"),
        ("R(WB) switching", f"[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,0,50,50,0)_100", f"{data}", f"{selector}"),

    ],
    aes=[
        ("75R 50WB", "[8]"),
        ("100R 50WB", "[8]"),
        ("150R 50WB", "[8]"),
        ("200R 50WB", "[8]"),

        ("75R 50WB", "[24, 8]"),
        ("100R 50WB", "[24, 8]"),
        ("150R 50WB", "[24, 8]"),
        ("200R 50WB", "[24, 8]"),

        ("75R 50WB", "[24, 48, 24, 8]"),
        ("100R 50WB", "[24, 48, 24, 8]"),
        ("150R 50WB", "[24, 48, 24, 8]"),
        ("200R 50WB", "[24, 48, 24, 8]"),
    ],
    # y_ax = "Train Loss",
    x = "epochs", 
    # xlim = 300,
    xmin = 0,
    ylim = .7,
    ymin = .4,
    hide_legend = False
    # vbars = [(149, "lightgrey"), (169, "lightgrey")],
)

# %%
import utils
import importlib
importlib.reload(utils)
        
sel = 200

utils.plot_seaborn(
    model_paths=[
        ("R(WB) switching", "[8]_(0.001,0.0001,0.0001)_(200,0,50,50,0)_100", "vals", "med"),
        ("R(WB) switching", "[8]_(0.001,0.0001,0.0001)_(200,0,50,50,0)_100", "cr_vals", "med"),
        ("WB", "[8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),

        ("R(WB) switching", "[24, 8]_(0.001,0.0001,0.0001)_(200,0,50,50,0)_100", "vals", "med"),
        ("R(WB) switching", "[24, 8]_(0.001,0.0001,0.0001)_(200,0,50,50,0)_100", "cr_vals", "med"),
        ("WB", "[24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),

        # ("R(WB) switching", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,0,50,50,0)_100", "vals", "med"),
        # ("R(WB) switching", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,0,50,50,0)_100", "cr_vals", "med"),

        # ("", "", "vals", "avg"),
    ],
    aes=[
        (f"{sel}R 50B", "[8]"),
        (f"{sel+50}R", "[8]"),
        ("WB", "[8]"),

        (f"{sel}R 50B", "[24, 8]"),
        (f"{sel+50}R", "[24, 8]"),
        ("WB", "[24, 8]"),

        # (f"{sel}R 50B", "[24, 48, 24, 8]"),
        # (f"{sel+50}R", "[24, 48, 24, 8]"),

        # ("", ""),
    ],
    x="epochs", 
    # xlim = 300,
    xmin=0,
    ylim = .7,
    ymin=.35,
    hide_legend=False,
    vbars = [(100, "lightgrey")],
)
# Out:
# Avg over last 5 epochs on 200R 50B,[8],med: 0.4841 in 290.00056220588255s
# Avg over last 5 epochs on 250R,[8],med: 0.4923 in 213.85899595098041s
# Avg over last 5 epochs on WB,[8],med: 0.4733 in 483.6654552899998s
# Avg over last 5 epochs on 200R 50B,[24, 8],med: 0.4472 in 395.9610135631068s
# Avg over last 5 epochs on 250R,[24, 8],med: 0.4487 in 262.7135160582523s
# Avg over last 5 epochs on WB,[24, 8],med: 0.44279999999999997 in 757.9136882699995s

# %%
import utils
import importlib
importlib.reload(utils)
        
utils.plot_seaborn(
    model_paths=[
        ("R(WB) switching", "[8]_(0.001,0.0001,0.0001)_(200,0,50,50,0)_100", "vals", "med"),
        ("learning_rate/[8]", "[8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", "vals", "med"),
        
        ("R(WB) switching", "[24, 8]_(0.001,0.0001,0.0001)_(200,0,50,50,0)_100", "vals", "med"),
        ("learning_rate/[24, 8]", "[24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", "vals", "med"),

        ("R(WB) switching", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,0,50,50,0)_100", "vals", "med"),
        ("learning_rate/[24, 48, 24, 8]", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", "vals", "med"),

        # ("", "", "vals", "avg"),
    ],
    aes=[
        ("200R 50B", "[8]"),
        ("200B", "[8]"),

        ("200R 50B", "[24, 8]"),
        ("200B", "[24, 8]"),

        ("200R 50B", "[24, 48, 24, 8]"),
        ("200B", "[24, 48, 24, 8]"),

        # ("", ""),
    ],
    x="epochs", 
    # xlim = 300,
    xmin=0,
    ylim = .7,
    ymin=.35,
    hide_legend=False,
    vbars = [(149, "lightgrey")],
)
# Out:
# Avg over last 5 epochs on 200R 50B,[8],med: 0.4841 in 290.00056220588255s
# Avg over last 5 epochs on 200B,[8],med: 0.47940000000000005 in 501.10176714705887s
# Avg over last 5 epochs on 200R 50B,[24, 8],med: 0.4472 in 395.9610135631068s
# Avg over last 5 epochs on 200B,[24, 8],med: 0.44394999999999996 in 779.952086647058s
# Avg over last 5 epochs on 200R 50B,[24, 48, 24, 8],med: 0.4341 in 604.5177287961164s
# Avg over last 5 epochs on 200B,[24, 48, 24, 8],med: 0.4335 in 1298.4482278811884s

# %% [markdown]
# ### ReLU to BSpline

# %% [markdown]
# Param sweep: switching

# %%
import importlib, utils
importlib.reload(utils)

# arch="[24, 48, 24, 8]"
selector = "med"
data = "vals"

utils.plot_seaborn(
    # title="ReLU vs BSpline, W&B_lr=0.001 BS_lr=0.0001 ctrl=3",
    model_paths=[
        ("RB switching", f"[8]_(0.001,0.0001,0.0001)_(100,50,0,50,0)_100", f"{data}", f"{selector}"),
        ("RB switching", f"[8]_(0.001,0.0001,0.0001)_(150,50,0,50,0)_100", f"{data}", f"{selector}"),
        ("RB switching", f"[8]_(0.001,0.0001,0.0001)_(200,50,0,50,0)_100", f"{data}", f"{selector}"),
        ("RB switching", f"[8]_(0.001,0.0001,0.0001)_(250,50,0,50,0)_100", f"{data}", f"{selector}"),

        ("RB switching", f"[24, 8]_(0.001,0.0001,0.0001)_(100,50,0,50,0)_100", f"{data}", f"{selector}"),
        ("RB switching", f"[24, 8]_(0.001,0.0001,0.0001)_(150,50,0,50,0)_100", f"{data}", f"{selector}"),
        ("RB switching", f"[24, 8]_(0.001,0.0001,0.0001)_(200,50,0,50,0)_100", f"{data}", f"{selector}"),
        ("RB switching", f"[24, 8]_(0.001,0.0001,0.0001)_(250,50,0,50,0)_100", f"{data}", f"{selector}"),

    ],
    aes=[
        ("100R 50B", "[8]"),
        ("150R 50B", "[8]"),
        ("200R 50B", "[8]"),
        ("250R 50B", "[8]"),

        ("100R 50B", "[24, 8]"),
        ("150R 50B", "[24, 8]"),
        ("200R 50B", "[24, 8]"),
        ("250R 50B", "[24, 8]"),
    ],
    # y_ax = "Train Loss",
    x = "epochs", 
    # xlim = 300,
    xmin = 0,
    ylim = .7,
    ymin = .4,
    hide_legend = False
    # vbars = [(149, "lightgrey"), (169, "lightgrey")],
)
# Out:
# [2025-01-16 13:14:15,994] [WARNING] [real_accelerator.py:174:get_accelerator] Setting accelerator to CPU. If you have GPU or other accelerator, we were unable to detect it.
# [2025-01-16 13:14:16,037] [INFO] [real_accelerator.py:219:get_accelerator] Setting ds_accelerator to cpu (auto detect)
# ...
# Avg over last 5 epochs on 100R 50B,[8],med: 0.5071 in 205.3287204257425s
# Avg over last 5 epochs on 150R 50B,[8],med: 0.4831 in 247.355979990099s
# Avg over last 5 epochs on 200R 50B,[8],med: 0.4832 in 290.98146971287105s
# Avg over last 5 epochs on 250R 50B,[8],med: 0.4842 in 334.10332942718435s
# Avg over last 5 epochs on 100R 50B,[24, 8],med: 0.4461 in 284.83573534313723s
# Avg over last 5 epochs on 150R 50B,[24, 8],med: 0.4408 in 337.9567104059408s
# Avg over last 5 epochs on 200R 50B,[24, 8],med: 0.4375 in 391.2594189901959s
# Avg over last 5 epochs on 250R 50B,[24, 8],med: 0.4373 in 446.0190738217825s

# %%
import importlib, utils
importlib.reload(utils)

# arch="[24, 48, 24, 8]"
selector = "med"
data = "vals"

utils.plot_seaborn(
    # title="ReLU vs BSpline, W&B_lr=0.001 BS_lr=0.0001 ctrl=3",
    model_paths=[
        ("RB switching", f"[8]_(0.001,0.0001,0.0001)_(200,50,0,50,0)_100", "vals", f"{selector}"),
        ("RB switching", f"[8]_(0.001,0.0001,0.0001)_(200,50,0,50,0)_100", "cr_vals", f"{selector}"),
        ("WB", "[8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),

        ("RB switching", f"[24, 8]_(0.001,0.0001,0.0001)_(200,50,0,50,0)_100", "vals", f"{selector}"),
        ("RB switching", f"[24, 8]_(0.001,0.0001,0.0001)_(200,50,0,50,0)_100", "cr_vals", f"{selector}"),
        ("WB", "[24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),

        ("RB switching", f"[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,50,0,50,0)_100", "vals", f"{selector}"),
        ("RB switching", f"[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,50,0,50,0)_100", "cr_vals", f"{selector}"),
        ("WB", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),

    ],
    aes=[
        ("200R 50B", "[8]"),
        ("250R", "[8]"),
        ("200WB", "[8]"),

        ("200R 50B", "[24, 8]"),
        ("250R", "[24, 8]"),
        ("200WB", "[24, 8]"),

        ("200R 50B", "[24, 48, 24, 8]"),
        ("250R", "[24, 48, 24, 8]"),
        ("200WB", "[24, 48, 24, 8]"),
    ],
    # y_ax = "Train Loss",
    x = "time", 
    # xlim = 300,
    xmin = 0,
    ylim = .65,
    ymin = .35,
    hide_legend = False
    # vbars = [(149, "lightgrey"), (169, "lightgrey")],
)
# Out:
# Avg over last 5 epochs on 200R 50B,[8],med: 0.4832 in 290.98146971287105s
# Avg over last 5 epochs on 250R,[8],med: 0.4951 in 230.01153724752456s
# Avg over last 5 epochs on 200WB,[8],med: 0.4733 in 483.6654552899998s
# Avg over last 5 epochs on 200R 50B,[24, 8],med: 0.4375 in 391.2594189901959s
# Avg over last 5 epochs on 250R,[24, 8],med: 0.45255 in 274.05602569607817s
# Avg over last 5 epochs on 200WB,[24, 8],med: 0.44279999999999997 in 757.9136882699995s
# Avg over last 5 epochs on 200R 50B,[24, 48, 24, 8],med: 0.40945 in 591.4595634711541s
# Avg over last 5 epochs on 250R,[24, 48, 24, 8],med: 0.4316 in 377.8175238269232s
# Avg over last 5 epochs on 200WB,[24, 48, 24, 8],med: 0.4335 in 1298.4482278811884s

# %% [markdown]
# ### ReLU to BSpline to LSpline

# %%
import importlib, utils
importlib.reload(utils)

# arch="[24, 48, 24, 8]"
selector = "med"
data = "vals"

utils.plot_seaborn(
    # title="ReLU vs BSpline, W&B_lr=0.001 BS_lr=0.0001 ctrl=3",
    model_paths=[
        ("RBL", "[8]_(0.001,0.0001,0.0001)_(150,5,0,0,50)_100", "vals", f"{selector}"),
        ("RBL", "[24, 8]_(0.001,0.0001,0.0001)_(150,5,0,0,50)_100", "cr_vals", f"{selector}"),
        ("RBL", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(150,5,0,0,50)_100", "vals", f"{selector}"),
    ],
    aes=[
        ("150R 5B", "[8]"),
        ("150R 5B", "[24, 8]"),
        ("150R 5B", "[24, 48, 24, 8]"),
    ],
    # y_ax = "Train Loss",
    x = "epochs", 
    # xlim = 300,
    xmin = 0,
    ylim = .7,
    ymin = .4,
    hide_legend = False
    # vbars = [(149, "lightgrey"), (169, "lightgrey")],
)
# Out:
# [2025-01-16 13:57:08,597] [WARNING] [real_accelerator.py:174:get_accelerator] Setting accelerator to CPU. If you have GPU or other accelerator, we were unable to detect it.
# [2025-01-16 13:57:08,641] [INFO] [real_accelerator.py:219:get_accelerator] Setting ds_accelerator to cpu (auto detect)
# ...
# Avg over last 5 epochs on 150R 5B,[8],med: 0.46525 in 203.5710608400001s
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 8
#       5 selector = "med"
#       6 data = "vals"
# ----> 8 utils.plot_seaborn(
#       9     # title="ReLU vs BSpline, W&B_lr=0.001 BS_lr=0.0001 ctrl=3",
#      10     model_paths=[
#      11         ("RBL", "[8]_(0.001,0.0001,0.0001)_(150,5,0,0,50)_100", "vals", f"{selector}"),
#      12         ("RBL", "[24, 8]_(0.001,0.0001,0.0001)_(150,5,0,0,50)_100", "cr_vals", f"{selector}"),
# ...

# %% [markdown]
# ### ReLU to WBSpline to LSpline

# %% [markdown]
# ### ReLU to WBSpline to BSpline

# %%
import importlib, utils
importlib.reload(utils)

selector = "med"
data = "vals"

utils.plot_seaborn(
    # title="ReLU vs BSpline, W&B_lr=0.001 BS_lr=0.0001 ctrl=3",
    model_paths=[

        ("", "[8]_(0.001,0.0001,0.0001)_(200,10,50,100,0)_100", "vals", f"{selector}"),
        ("", "[8]_(0.001,0.0001,0.0001)_(200,10,50,100,0)_100", "cr_vals", f"{selector}"),

    ],
    aes=[
        ("200R 10B 50WB", "[8]"),
        ("260R", "[8]"),

        ("200R 10B 50 WB", "[24, 8]"),
        ("260R", "[24, 8]"),
    ],
    # y_ax = "Train Loss",
    x = "epochs", 
    # xlim = 300,
    xmin = 0,
    ylim = .6,
    ymin = .4,
    hide_legend = False,
    cutoff = 260-1,
    vbars = [(199, "lightgrey"), (209, "lightgrey")],
)

# %% [markdown]
# ### ReLU to WBSpline to BSpline

# %%
import importlib, utils
importlib.reload(utils)

selector = "med"
data = "vals"

utils.plot_seaborn(
    # title="ReLU vs BSpline, W&B_lr=0.001 BS_lr=0.0001 ctrl=3",
    model_paths=[

        ("", "[8]_(0.001,0.0001,0.0001)_(200,10,50,100,0)_100_bothfirst", "vals", f"{selector}"),
        ("", "[8]_(0.001,0.0001,0.0001)_(200,10,50,100,0)_100_bothfirst", "cr_vals", f"{selector}"),
        
    ],
    aes=[
        ("200R 50WB 10B", "[8]"),
        ("260R", "[8]"),

        # ("200R 50WB 10B", "[24, 8]"),
        # ("260R", "[24, 8]"),
    ],
    # y_ax = "Train Loss",
    x = "epochs", 
    # xlim = 300,
    xmin = 0,
    ylim = .6,
    ymin = .4,
    hide_legend = False,
    cutoff = 260-1,
    vbars = [(199, "lightgrey"), (209, "lightgrey")],
)

# %% [markdown]
# ### ReLU to WBSpline to Linear

# %%
import importlib, utils
importlib.reload(utils)

selector = "med"
data = "vals"

utils.plot_seaborn(
    # title="ReLU vs BSpline, W&B_lr=0.001 BS_lr=0.0001 ctrl=3",
    model_paths=[

        # 200 relu, 50 both, 200 comp, 100 lspline
        ("R(WB)L", "[24, 8]_(0.001,0.0001,0.0001)_(200,0,50,200,100)_100", "vals", f"{selector}"),
        ("R(WB)L", "[24, 8]_(0.001,0.0001,0.0001)_(200,0,50,200,100)_100", "cr_vals", f"{selector}"),

        ("", "[24, 8]_(0.001,0.0001,0.0001)_(200,0,50,200,100)_100", "vals", f"{selector}"),
        ("", "[24, 8]_(0.001,0.0001,0.0001)_(200,0,50,200,100)_100", "cr_vals", f"{selector}"),
        
        ("", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,0,50,200,100)_100", "vals", f"{selector}"),
        ("", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,0,50,200,100)_100", "cr_vals", f"{selector}"),
    ],
    aes=[
        ("200R 50WB 100L", "[8]"),
        ("400R", "[8]"),

        ("200R 50WB 100L", "[24, 8]"),
        ("400R", "[24, 8]"),

        ("200R 50WB 100L", "[24, 48, 24, 8]"),
        ("400R", "[24, 48, 24, 8]"),
    ],
    # y_ax = "Train Loss",
    x = "epochs", 
    # xlim = 300,
    xmin = 0,
    ylim = .55,
    ymin = .35,
    hide_legend = False,
    # cutoff = 260-1,
    vbars = [(199, "lightgrey"), (209, "lightgrey")],
)
# Out:
# Avg over last 5 epochs on 200R 50WB 100L,[8],med: 0.41390000000000005 in 598.6454383490567s
# Avg over last 5 epochs on 400R,[8],med: 0.4424 in 439.55451165714294s
# Avg over last 5 epochs on 200R 50WB 100L,[24, 8],med: 0.41575 in 788.8891535490196s
# Avg over last 5 epochs on 400R,[24, 8],med: 0.44555 in 435.5700471960787s

# %% [markdown]
# ### ReLU to BSpline to LSpline

# %%
import importlib, utils
importlib.reload(utils)

selector = "med"
data = "vals"

utils.plot_seaborn(
    # title="ReLU vs BSpline, W&B_lr=0.001 BS_lr=0.0001 ctrl=3",
    model_paths=[

        # 200 relu, 10 bspline, 0 both, 150 comp, 100 lspline
        ("RBL", "[8]_(0.001,0.0001,0.0001)_(200,10,0,150,100)_100", "vals", f"{selector}"),
        ("RBL", "[8]_(0.001,0.0001,0.0001)_(200,10,0,150,100)_100", "cr_vals", f"{selector}"),

        ("RBL", "[24, 8]_(0.001,0.0001,0.0001)_(200,10,0,150,100)_100", "vals", f"{selector}"),
        ("RBL", "[24, 8]_(0.001,0.0001,0.0001)_(200,10,0,150,100)_100", "cr_vals", f"{selector}"),

        ("RBL", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,10,0,150,100)_100", "vals", f"{selector}"),
        ("RBL", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,10,0,150,100)_100", "cr_vals", f"{selector}"),

    ],
    aes=[
        ("200R 10B 100L", "[8]"),
        ("350R", "[8]"),

        ("200R 10B 100L", "[24, 8]"),
        ("350R", "[24, 8]"),

        ("200R 10B 100L", "[24, 48, 24, 8]"),
        ("350R", "[24, 48, 24, 8]"),
    ],
    # y_ax = "Train Loss",
    x = "epochs", 
    # xlim = 300,
    xmin = 0,
    ylim = .55,
    ymin = .35,
    hide_legend = False,
    # cutoff = 260-1,
    vbars = [(199, "lightgrey"), (209, "lightgrey")],
)
# Out:
# Avg over last 5 epochs on 200R 10B 100L,[8],med: 0.4606 in 330.39935934653454s
# Avg over last 5 epochs on 350R,[8],med: 0.4875 in 315.52793913861365s
# Avg over last 5 epochs on 200R 10B 100L,[24, 8],med: 0.427 in 439.57349047572836s
# Avg over last 5 epochs on 350R,[24, 8],med: 0.4448 in 385.82155007766977s
# Avg over last 5 epochs on 200R 10B 100L,[24, 48, 24, 8],med: 0.4137 in 654.1745260485437s
# Avg over last 5 epochs on 350R,[24, 48, 24, 8],med: 0.4328 in 533.7346104757279s
