# %% [markdown]
# ## A Notebook for the graphs I'm presenting in the paper

# %% [markdown]
# ### Control Points

# %%
import importlib, utils
importlib.reload(utils)

arch="24, 48, 24, 8"
selector = "med"
data = "trains"

utils.plot_seaborn(
    # title="ReLU vs BSpline, W&B_lr=0.001 BS_lr=0.0001 ctrl=3",
    model_paths=[
        # throw a relu in here - actually looks like advantage for less
        # should note on how many prev research used
        (f"learning_rate/[{arch}]", f"[{arch}]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", f"{selector}"),
        ("control points test", f"[{arch}]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),
        ("control points test", f"[{arch}]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100_5", "vals", f"{selector}"),
        ("control points test", f"[{arch}]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100_11", "vals", f"{selector}"),
        ("control points test", f"[{arch}]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100_23", "vals", f"{selector}"),
        ("control points test", f"[{arch}]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100_55", "vals", f"{selector}"),
        ("control points test", f"[{arch}]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100_111", "vals", f"{selector}"),
    ],
    aes=[
        ("ReLU (ctrl=0)", f"[{arch}]"),
        ("ctrl=3", f"[{arch}]"),
        ("ctrl=5", f"[{arch}]"),
        ("ctrl=11", f"[{arch}]"),
        ("ctrl=23", f"[{arch}]"),
        ("ctrl=55", f"[{arch}]"),
        ("ctrl=111", f"[{arch}]"),
    ],
    # y_ax = "Train Loss",
    x = "epochs", 
    # xlim = 300,
    xmin = 0,
    ylim = .6,
    ymin = .4,
    hide_legend = False
    # vbars = [(149, "lightgrey"), (169, "lightgrey")],
)
# Out:
# [2025-01-27 01:05:55,480] [WARNING] [real_accelerator.py:174:get_accelerator] Setting accelerator to CPU. If you have GPU or other accelerator, we were unable to detect it.
# [2025-01-27 01:05:55,516] [INFO] [real_accelerator.py:219:get_accelerator] Setting ds_accelerator to cpu (auto detect)
# ...
# Avg over last 5 epochs on ReLU (ctrl=0),[24, 48, 24, 8],med: 0.439 in 308.6244620666665s
# Avg over last 5 epochs on ctrl=3,[24, 48, 24, 8],med: 0.4245 in 1260.1912225588235s
# Avg over last 5 epochs on ctrl=5,[24, 48, 24, 8],med: 0.4232 in 1257.5977450399994s
# Avg over last 5 epochs on ctrl=11,[24, 48, 24, 8],med: 0.42910000000000004 in 1276.7183422000003s
# Avg over last 5 epochs on ctrl=23,[24, 48, 24, 8],med: 0.4281 in 1278.813474712871s
# Avg over last 5 epochs on ctrl=55,[24, 48, 24, 8],med: 0.4265 in 1326.404544514563s
# Avg over last 5 epochs on ctrl=111,[24, 48, 24, 8],med: 0.4414 in 1320.5808578058256s

# %% [markdown]
# ### ReLU Learning Rate

# %%
import importlib, utils
importlib.reload(utils)

arch1 = "8"
arch2 = "24, 8"
arch3 = "24, 48, 24, 8"
selector = "med"
data = "vals"

utils.plot_seaborn(
    model_paths=[
        (f"learning_rate/[{arch1}]", f"[{arch1}]_(0.005,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", f"{selector}"),
        (f"learning_rate/[{arch1}]", f"[{arch1}]_(0.0025,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", f"{selector}"),
        (f"learning_rate/[{arch1}]", f"[{arch1}]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", f"{selector}"),
        (f"learning_rate/[{arch1}]", f"[{arch1}]_(0.00075,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", f"{selector}"),
        (f"learning_rate/[{arch1}]", f"[{arch1}]_(0.0005,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", f"{selector}"),

        (f"learning_rate/[{arch2}]", f"[{arch2}]_(0.005,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", f"{selector}"),
        (f"learning_rate/[{arch2}]", f"[{arch2}]_(0.0025,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", f"{selector}"),
        (f"learning_rate/[{arch2}]", f"[{arch2}]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", f"{selector}"),
        (f"learning_rate/[{arch2}]", f"[{arch2}]_(0.00075,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", f"{selector}"),
        (f"learning_rate/[{arch2}]", f"[{arch2}]_(0.0005,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", f"{selector}"),

        (f"learning_rate/[{arch3}]", f"[{arch3}]_(0.005,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", f"{selector}"),
        (f"learning_rate/[{arch3}]", f"[{arch3}]_(0.0025,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", f"{selector}"),
        (f"learning_rate/[{arch3}]", f"[{arch3}]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", f"{selector}"),
        (f"learning_rate/[{arch3}]", f"[{arch3}]_(0.00075,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", f"{selector}"),
        (f"learning_rate/[{arch3}]", f"[{arch3}]_(0.0005,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", f"{selector}"),
    ],
    aes=[
        ("ReLU lr=0.005", f"[{arch1}]"),
        ("ReLU lr=0.0025", f"[{arch1}]"),
        ("ReLU lr=0.001", f"[{arch1}]"),
        ("ReLU lr=0.0075", f"[{arch1}]"),
        ("ReLU lr=0.0005", f"[{arch1}]"),

        ("ReLU lr=0.005", f"[{arch2}]"),
        ("ReLU lr=0.0025", f"[{arch2}]"),
        ("ReLU lr=0.001", f"[{arch2}]"),
        ("ReLU lr=0.0075", f"[{arch2}]"),
        ("ReLU lr=0.0005", f"[{arch2}]"),

        ("ReLU lr=0.005", f"[{arch3}]"),
        ("ReLU lr=0.0025", f"[{arch3}]"),
        ("ReLU lr=0.001", f"[{arch3}]"),
        ("ReLU lr=0.0075", f"[{arch3}]"),
        ("ReLU lr=0.0005", f"[{arch3}]"),
    ],
    # y_ax = "Train Loss",
    x = "epochs", 
    # xlim = 300,
    xmin = 0,
    ylim = .8,
    ymin = .4,
    hide_legend = False
    # vbars = [(149, "lightgrey"), (169, "lightgrey")],
)

# %% [markdown]
# ### BSpline Learning Rate

# %%
importlib.reload(utils)
arch1 = "8"
arch2 = "24, 8"
arch3 = "24, 48, 24, 8"

selector = "med"
data = "vals"

utils.plot_seaborn(
    model_paths=[
        (f"learning_rate/[{arch1}]", f"[{arch1}]_(0.001,0.0005,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),
        (f"learning_rate/[{arch1}]", f"[{arch1}]_(0.001,0.00025,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),
        (f"learning_rate/[{arch1}]", f"[{arch1}]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),
        (f"learning_rate/[{arch1}]", f"[{arch1}]_(0.001,7.5e-05,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),
        (f"learning_rate/[{arch1}]", f"[{arch1}]_(0.001,5e-05,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),
        
        (f"learning_rate/[{arch2}]", f"[{arch2}]_(0.001,0.0005,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),
        (f"learning_rate/[{arch2}]", f"[{arch2}]_(0.001,0.00025,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),
        (f"learning_rate/[{arch2}]", f"[{arch2}]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),
        (f"learning_rate/[{arch2}]", f"[{arch2}]_(0.001,7.5e-05,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),
        (f"learning_rate/[{arch2}]", f"[{arch2}]_(0.001,5e-05,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),
        
        (f"learning_rate/[{arch3}]", f"[{arch3}]_(0.001,0.0005,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),
        (f"learning_rate/[{arch3}]", f"[{arch3}]_(0.001,0.00025,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),
        (f"learning_rate/[{arch3}]", f"[{arch3}]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),
        (f"learning_rate/[{arch3}]", f"[{arch3}]_(0.001,7.5e-05,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),
        (f"learning_rate/[{arch3}]", f"[{arch3}]_(0.001,5e-05,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),
    ],
    aes=[
        ("BSpline lr=0.0005", f"[{arch1}]"),
        ("BSpline lr=0.00025", f"[{arch1}]"),
        ("BSpline lr=0.0001", f"[{arch1}]"),
        ("BSpline lr=0.000075", f"[{arch1}]"),
        ("BSpline lr=0.000005", f"[{arch1}]"),

        ("BSpline lr=0.0005", f"[{arch2}]"),
        ("BSpline lr=0.00025", f"[{arch2}]"),
        ("BSpline lr=0.0001", f"[{arch2}]"),
        ("BSpline lr=0.000075", f"[{arch2}]"),
        ("BSpline lr=0.000005", f"[{arch2}]"),

        ("BSpline lr=0.0005", f"[{arch3}]"),
        ("BSpline lr=0.00025", f"[{arch3}]"),
        ("BSpline lr=0.0001", f"[{arch3}]"),
        ("BSpline lr=0.000075", f"[{arch3}]"),
        ("BSpline lr=0.000005", f"[{arch3}]"),
    ],
    # y_ax = "Train Loss",
    x = "epochs", 
    # xlim = 300,
    xmin = 0,
    ylim = .65,
    ymin = .35,
    hide_legend = False
    # vbars = [(149, "lightgrey"), (169, "lightgrey")],
)

# %% [markdown]
# ### ReLU vs BSpline (same layers)

# %%
import importlib, utils
importlib.reload(utils)

selector = "med"
data = "vals"

utils.plot_seaborn(
    # title="ReLU vs BSpline, W&B_lr=0.001 BS_lr=0.0001 ctrl=3",
    model_paths=[
        ("learning_rate/[8]", "[8]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", f"{data}", f"{selector}"),
        ("learning_rate/[8]", "[8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", f"{data}", f"{selector}"),

        ("learning_rate/[24, 8]", "[24, 8]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", f"{data}", f"{selector}"),
        ("learning_rate/[24, 8]", "[24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", f"{data}", f"{selector}"),

        ("learning_rate/[24, 48, 24, 8]", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", f"{data}", f"{selector}"),
        ("learning_rate/[24, 48, 24, 8]", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", f"{data}", f"{selector}"),
    ],
    aes=[
        ("ReLU", "[8]"),
        ("BSpline", "[8]"),
        ("ReLU", "[24, 8]"),
        ("BSpline", "[24, 8]"),
        ("ReLU", "[24, 48, 24, 8]"),
        ("BSpline", "[24, 48, 24, 8]"),
    ],
    # palette=["black", "blue"],
    # y_ax = "Train Loss",
    x="epochs", 
    # xlim = 300,
    xmin=0,
    ylim = .7,
    ymin=.3,
    hide_legend=False
    # vbars = [(149, "lightgrey"), (169, "lightgrey")],
)
# Out:
# Avg over last 5 epochs on ReLU,[8],med: 0.4868 in 191.56679745544545s
# Avg over last 5 epochs on BSpline,[8],med: 0.47940000000000005 in 501.10176714705887s
# Avg over last 5 epochs on ReLU,[24, 8],med: 0.4644 in 230.9543103960394s
# Avg over last 5 epochs on BSpline,[24, 8],med: 0.44394999999999996 in 779.952086647058s
# Avg over last 5 epochs on ReLU,[24, 48, 24, 8],med: 0.439 in 308.6244620666665s
# Avg over last 5 epochs on BSpline,[24, 48, 24, 8],med: 0.4335 in 1298.4482278811884s

# %% [markdown]
# ### ReLU v BSpline: Parameter Control

# %%
import importlib, utils
importlib.reload(utils)

arch="arch"
selector = "med"
data = "vals"

utils.plot_seaborn(
    # title="ReLU vs BSpline, W&B_lr=0.001 BS_lr=0.0001 ctrl=3",
    model_paths=[
        ("param control", "[11]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", f"{data}", f"{selector}"),
        ("learning_rate/[8]", "[8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", f"{data}", f"{selector}"),

        ("param control", "[30, 8]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", f"{data}", f"{selector}"),
        ("learning_rate/[24, 8]", "[24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", f"{data}", f"{selector}"),

        ("param control", "[26, 50, 26, 8]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", f"{data}", f"{selector}"),
        ("learning_rate/[24, 48, 24, 8]", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", f"{data}", f"{selector}")

        # ("param control", "[26, 50, 98, 50, 26, 8]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", f"{data}", f"{selector}"),
    ],
    aes=[
        ("ReLU", "110"),
        ("BSpline", "110"),
        ("ReLU", "530"),
        ("BSpline", "530"),
        ("ReLU", "3.1K"),
        ("BSpline", "3.1K"),
    ],
    aes2="Parameters",
    x="epochs", 
    # xlim = 300,
    xmin=0,
    ylim = .7,
    ymin=.3,
    hide_legend=False
)
# Out:
# Avg over last 5 epochs on ReLU,110,med: 0.4929 in 174.48120867961165s
# Avg over last 5 epochs on BSpline,110,med: 0.47940000000000005 in 501.10176714705887s
# Avg over last 5 epochs on ReLU,530,med: 0.46004999999999996 in 217.42518939215682s
# Avg over last 5 epochs on BSpline,530,med: 0.44394999999999996 in 779.952086647058s
# Avg over last 5 epochs on ReLU,3.1K,med: 0.44205 in 300.4757484599999s
# Avg over last 5 epochs on BSpline,3.1K,med: 0.4335 in 1298.4482278811884s

# %% [markdown]
# ### ReLU v BSpline: FLOPs Control

# %%
import importlib, utils
importlib.reload(utils)

arch="arch"
selector = "med"
data = "vals"

utils.plot_seaborn(
    # title="ReLU vs BSpline, W&B_lr=0.001 BS_lr=0.0001 ctrl=3",
    model_paths=[
        ("flops control", "[24]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", f"{data}", f"{selector}"),
        ("learning_rate/[8]", "[8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", f"{data}", f"{selector}"),

        ("flops control", "[64, 8]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", f"{data}", f"{selector}"),
        ("learning_rate/[24, 8]", "[24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", f"{data}", f"{selector}"),

        ("flops control", "[24, 96, 24, 8]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", f"{data}", f"{selector}"),
        ("learning_rate/[24, 48, 24, 8]", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", f"{data}", f"{selector}")

        # ("flops control", "[24, 48, 144, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", f"{data}", f"{selector}"),
    ],
    aes=[
        ("ReLU", "450"),
        ("BSpline", "450"),

        ("ReLU", "2k"),
        ("BSpline", "2k"),

        ("ReLU", "10k"),
        ("BSpline", "10k"),
    ],
    aes2="FLOPs/inp",
    x="epochs", 
    # xlim = 300,
    xmin=0,
    ylim = .7,
    ymin=.3,
    hide_legend=False
)
# Out:
# Avg over last 5 epochs on ReLU,450,med: 0.4851 in 180.38763337999998s
# Avg over last 5 epochs on BSpline,450,med: 0.47940000000000005 in 501.10176714705887s
# Avg over last 5 epochs on ReLU,2k,med: 0.4571 in 223.4844030654204s
# Avg over last 5 epochs on BSpline,2k,med: 0.44394999999999996 in 779.952086647058s
# Avg over last 5 epochs on ReLU,10k,med: 0.4331 in 317.8652987920793s
# Avg over last 5 epochs on BSpline,10k,med: 0.4335 in 1298.4482278811884s

# %% [markdown]
# ### ReLU v BSpline: Latency Control

# %%
import importlib, utils
importlib.reload(utils)

arch="arch"
selector = "med"
data = "vals"

utils.plot_seaborn(
    # title="ReLU vs BSpline, W&B_lr=0.001 BS_lr=0.0001 ctrl=3",
    model_paths=[
        ("lat control", "[16, 32, 64, 128, 64, 32, 16, 8]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", f"{data}", f"{selector}"),
        ("WB", "[8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", f"{data}", f"{selector}"),

        ("lat control", "[24, 48, 96, 192, 384, 576, 384, 192, 96, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_50", f"{data}", f"{selector}"),
        ("lat control", "[16, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", f"{data}", f"{selector}"),

        # ("", "(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", f"{data}", f"{selector}"),
        ("WB", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", f"{data}", f"{selector}")
        
    ],
    aes=[
        ("ReLU", "30 us/in"),
        ("BSpline", "30 us/in"),

        ("ReLU", "60 us/in"),
        ("BSpline", "60 us/in"),

        ("BSpline", "120 us/in"),
    ],
    aes2="Forward Latency",
    x="epochs", 
    # xlim = 300,
    xmin=0,
    ylim = .7,
    ymin=.3,
    hide_legend=False
    # vbars = [(149, "lightgrey"), (169, "lightgrey")],
)
# Out:
# Avg over last 5 epochs on ReLU,30 us/in,med: 0.4422 in 603.9620668019801s
# Avg over last 5 epochs on BSpline,30 us/in,med: 0.4733 in 483.6654552899998s
# Avg over last 5 epochs on ReLU,60 us/in,med: 0.4477 in 7237.839162351852s
# Avg over last 5 epochs on BSpline,60 us/in,med: 0.43845 in 758.5787855900002s
# Avg over last 5 epochs on BSpline,120 us/in,med: 0.4335 in 1298.4482278811884s

# %% [markdown]
# ### ReLU to WBSpline

# %% [markdown]
# Sweeping pretraining epochs

# %%
import importlib, utils
importlib.reload(utils)

# arch="[24, 48, 24, 8]"
selector = "med"
data = "vals"

utils.plot_seaborn(
    model_paths=[
        ("R(WB) switching", f"[8]_(0.001,0.0001,0.0001)_(75,0,50,50,0)_100", f"{data}", f"{selector}"),
        ("R(WB) switching", f"[8]_(0.001,0.0001,0.0001)_(100,0,50,50,0)_100", f"{data}", f"{selector}"),
        ("R(WB) switching", f"[8]_(0.001,0.0001,0.0001)_(150,0,50,50,0)_100", f"{data}", f"{selector}"),
        ("R(WB) switching", f"[8]_(0.001,0.0001,0.0001)_(200,0,50,50,0)_100", f"{data}", f"{selector}"),

        ("R(WB) switching", f"[24, 8]_(0.001,0.0001,0.0001)_(75,0,50,50,0)_100", f"{data}", f"{selector}"),
        ("R(WB) switching", f"[24, 8]_(0.001,0.0001,0.0001)_(100,0,50,50,0)_100", f"{data}", f"{selector}"),
        ("R(WB) switching", f"[24, 8]_(0.001,0.0001,0.0001)_(150,0,50,50,0)_100", f"{data}", f"{selector}"),
        ("R(WB) switching", f"[24, 8]_(0.001,0.0001,0.0001)_(200,0,50,50,0)_100", f"{data}", f"{selector}"),

        ("R(WB) switching", f"[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(75,0,50,50,0)_100", f"{data}", f"{selector}"),
        ("R(WB) switching", f"[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(100,0,50,50,0)_100", f"{data}", f"{selector}"),
        ("R(WB) switching", f"[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(150,0,50,50,0)_100", f"{data}", f"{selector}"),
        ("R(WB) switching", f"[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,0,50,50,0)_100", f"{data}", f"{selector}"),

    ],
    aes=[
        ("75R 50WB", "[8]"),
        ("100R 50WB", "[8]"),
        ("150R 50WB", "[8]"),
        ("200R 50WB", "[8]"),

        ("75R 50WB", "[24, 8]"),
        ("100R 50WB", "[24, 8]"),
        ("150R 50WB", "[24, 8]"),
        ("200R 50WB", "[24, 8]"),

        ("75R 50WB", "[24, 48, 24, 8]"),
        ("100R 50WB", "[24, 48, 24, 8]"),
        ("150R 50WB", "[24, 48, 24, 8]"),
        ("200R 50WB", "[24, 48, 24, 8]"),
    ],
    # y_ax = "Train Loss",
    x = "epochs", 
    # xlim = 300,
    xmin = 0,
    ylim = .7,
    ymin = .4,
    hide_legend = False
    # vbars = [(149, "lightgrey"), (169, "lightgrey")],
)
# Out:
# Avg over last 5 epochs on 75R 50WB,[8],med: 0.50135 in 200.5456713823529s
# Avg over last 5 epochs on 100R 50WB,[8],med: 0.49785 in 205.38376537500017s
# Avg over last 5 epochs on 150R 50WB,[8],med: 0.4874 in 253.94785319000007s
# Avg over last 5 epochs on 200R 50WB,[8],med: 0.4841 in 290.00056220588255s
# Avg over last 5 epochs on 75R 50WB,[24, 8],med: 0.4631 in 280.3384075742575s
# Avg over last 5 epochs on 100R 50WB,[24, 8],med: 0.4567 in 303.1838573267328s
# Avg over last 5 epochs on 150R 50WB,[24, 8],med: 0.4511 in 352.44769751485137s
# Avg over last 5 epochs on 200R 50WB,[24, 8],med: 0.4472 in 395.9610135631068s
# Avg over last 5 epochs on 75R 50WB,[24, 48, 24, 8],med: 0.44284999999999997 in 437.48917056862734s
# Avg over last 5 epochs on 100R 50WB,[24, 48, 24, 8],med: 0.4432 in 472.62555957425735s
# Avg over last 5 epochs on 150R 50WB,[24, 48, 24, 8],med: 0.43565 in 530.0894295098037s
# Avg over last 5 epochs on 200R 50WB,[24, 48, 24, 8],med: 0.4341 in 604.5177287961164s

# %%
import utils
import importlib
importlib.reload(utils)
        
sel = 150
selector = "med"

utils.plot_seaborn(
    model_paths=[
        ("R(WB)", f"[8]_(0.001,0.0001,0.0001)_({150},0,50,50,0)_100", "vals", "med"),
        ("R(WB)", f"[8]_(0.001,0.0001,0.0001)_({150},0,50,50,0)_100", "cr_vals", "med"),
        ("WB", "[8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),

        ("R(WB)", f"[24, 8]_(0.001,0.0001,0.0001)_({150},0,50,50,0)_100", "vals", "med"),
        ("R(WB)", f"[24, 8]_(0.001,0.0001,0.0001)_({150},0,50,50,0)_100", "cr_vals", "med"),
        ("WB", "[24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),

        ("R(WB)", f"[24, 48, 24, 8]_(0.001,0.0001,0.0001)_({150},0,50,50,0)_100", "vals", "med"),
        ("R(WB)", f"[24, 48, 24, 8]_(0.001,0.0001,0.0001)_({150},0,50,50,0)_100", "cr_vals", "med"),
        ("WB", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),

    ],
    aes=[
        (f"{sel}R 50WB", "[8]"),
        (f"{sel+50}R", "[8]"),
        ("200WB", "[8]"),

        (f"{sel}R 50WB", "[24, 8]"),
        (f"{sel+50}R", "[24, 8]"),
        ("200WB", "[24, 8]"),

        (f"{sel}R 50WB", "[24, 48, 24, 8]"),
        (f"{sel+50}R", "[24, 48, 24, 8]"),
        ("200WB", "[24, 48, 24, 8]"),

        # ("", ""),
    ],
    x="epochs", 
    ylim = .6,
    ymin=.4,
    vbars = [(148, "lightgrey")],
)
# Out:
# Avg over last 5 epochs on 150R 50WB,[8],med: 0.4874 in 253.94785319000007s
# Avg over last 5 epochs on 200R,[8],med: 0.49395 in 175.48539656999998s
# Avg over last 5 epochs on 200WB,[8],med: 0.4733 in 483.6654552899998s
# Avg over last 5 epochs on 150R 50WB,[24, 8],med: 0.4511 in 352.44769751485137s
# Avg over last 5 epochs on 200R,[24, 8],med: 0.4545 in 213.8850091980197s
# Avg over last 5 epochs on 200WB,[24, 8],med: 0.44279999999999997 in 757.9136882699995s
# Avg over last 5 epochs on 150R 50WB,[24, 48, 24, 8],med: 0.43565 in 530.0894295098037s
# Avg over last 5 epochs on 200R,[24, 48, 24, 8],med: 0.4397 in 292.004070607843s
# Avg over last 5 epochs on 200WB,[24, 48, 24, 8],med: 0.4335 in 1298.4482278811884s

# %%
import utils
import importlib
importlib.reload(utils)
        
utils.plot_seaborn(
    model_paths=[
        ("R(WB)", "[8]_(0.001,0.0001,0.0001)_(200,0,50,50,0)_100", "vals", "med"),
        ("learning_rate/[8]", "[8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", "vals", "med"),
        
        ("R(WB)", "[24, 8]_(0.001,0.0001,0.0001)_(200,0,50,50,0)_100", "vals", "med"),
        ("learning_rate/[24, 8]", "[24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", "vals", "med"),

        ("R(WB)", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,0,50,50,0)_100", "vals", "med"),
        ("learning_rate/[24, 48, 24, 8]", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", "vals", "med"),

        # ("", "", "vals", "avg"),
    ],
    aes=[
        ("200R 50WB", "[8]"),
        ("200WB", "[8]"),

        ("200R 50WB", "[24, 8]"),
        ("200WB", "[24, 8]"),

        ("200R 50WB", "[24, 48, 24, 8]"),
        ("200WB", "[24, 48, 24, 8]"),

        # ("", ""),
    ],
    x="epochs", 
    # xlim = 300,
    xmin=0,
    ylim = .7,
    ymin=.35,
    hide_legend=False,
    vbars = [(149, "lightgrey")],
)
# Out:
# Avg over last 5 epochs on 200R 50WB,[8],med: 0.4841 in 290.00056220588255s
# Avg over last 5 epochs on 200WB,[8],med: 0.47940000000000005 in 501.10176714705887s
# Avg over last 5 epochs on 200R 50WB,[24, 8],med: 0.4472 in 395.9610135631068s
# Avg over last 5 epochs on 200WB,[24, 8],med: 0.44394999999999996 in 779.952086647058s
# Avg over last 5 epochs on 200R 50WB,[24, 48, 24, 8],med: 0.4341 in 604.5177287961164s
# Avg over last 5 epochs on 200WB,[24, 48, 24, 8],med: 0.4335 in 1298.4482278811884s

# %%
import utils
import importlib
importlib.reload(utils)
        
utils.plot_seaborn(
    model_paths=[
        # ("RB", "[8]_(0.001,0.0001,0.0001)_(['150R', '10B'])_100", "vals", "med"),
        ("WB at 0.0001", "[8]_(0.001,0.0001,0.0001)_(['150R', '50WB'])_100_wbs_lr0.0001", "vals", "med"),
        ("WB at 0.0001", "[8]_(0.001,0.0001,0.0001)_(['150R', '50WB'])_100_wbs_lr0.0001", "cr_vals", "med"),
        
        # ("RB", "[24, 8]_(0.001,0.0001,0.0001)_(['150R', '10B'])_100", "vals", "med"),
        ("WB at 0.0001", "[24, 8]_(0.001,0.0001,0.0001)_(['150R', '50WB'])_100_wbs_lr0.0001", "vals", "med"),
        ("WB at 0.0001", "[24, 8]_(0.001,0.0001,0.0001)_(['150R', '50WB'])_100_wbs_lr0.0001", "cr_vals", "med"),

        # ("RB", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(['150R', '10B'])_100", "vals", "med"),
        ("WB at 0.0001", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(['150R', '50WB'])_100_wbs_lr0.0001", "vals", "med"),
        ("WB at 0.0001", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(['150R', '50WB'])_100_wbs_lr0.0001", "cr_vals", "med"),

    ],
    aes=[
        # ("150R 50B", "[8]"),
        ("150R 50WB", "[8]"),
        ("200R", "[8]"),

        # ("150R 50B", "[24, 8]"),
        ("150R 50WB", "[24, 8]"),
        ("200R", "[24, 8]"),

        # ("150R 50B", "[24, 48, 24, 8]"),
        ("150R 50WB", "[24, 48, 24, 8]"),
        ("200R", "[24, 48, 24, 8]"),
    ],
    x="time", 
    ylim = .7,
    ymin=.35,
    # vbars = [(148, "lightgrey")],
)
# Out:
# Avg over last 5 epochs on 150R 50WB,[8],med: 0.4726 in 254.03184082524268s
# Avg over last 5 epochs on 200R,[8],med: 0.5013 in 175.0098003009708s
# Avg over last 5 epochs on 150R 50WB,[24, 8],med: 0.4345 in 350.3376870096154s
# Avg over last 5 epochs on 200R,[24, 8],med: 0.45985 in 213.99882394230778s
# Avg over last 5 epochs on 150R 50WB,[24, 48, 24, 8],med: 0.4114 in 545.6689133725491s
# Avg over last 5 epochs on 200R,[24, 48, 24, 8],med: 0.4376 in 300.37926679411754s

# %% [markdown]
# ### ReLU to BSpline

# %% [markdown]
# Param sweep: switching

# %%
import importlib, utils
importlib.reload(utils)

# arch="[24, 48, 24, 8]"
selector = "med"
data = "vals"

utils.plot_seaborn(
    # title="ReLU vs BSpline, W&B_lr=0.001 BS_lr=0.0001 ctrl=3",
    model_paths=[
        ("RB switching", f"[8]_(0.001,0.0001,0.0001)_(100,50,0,50,0)_100", f"{data}", f"{selector}"),
        ("RB switching", f"[8]_(0.001,0.0001,0.0001)_(150,50,0,50,0)_100", f"{data}", f"{selector}"),
        ("RB switching", f"[8]_(0.001,0.0001,0.0001)_(200,50,0,50,0)_100", f"{data}", f"{selector}"),
        ("RB switching", f"[8]_(0.001,0.0001,0.0001)_(250,50,0,50,0)_100", f"{data}", f"{selector}"),

        ("RB switching", f"[24, 8]_(0.001,0.0001,0.0001)_(100,50,0,50,0)_100", f"{data}", f"{selector}"),
        ("RB switching", f"[24, 8]_(0.001,0.0001,0.0001)_(150,50,0,50,0)_100", f"{data}", f"{selector}"),
        ("RB switching", f"[24, 8]_(0.001,0.0001,0.0001)_(200,50,0,50,0)_100", f"{data}", f"{selector}"),
        ("RB switching", f"[24, 8]_(0.001,0.0001,0.0001)_(250,50,0,50,0)_100", f"{data}", f"{selector}"),

    ],
    aes=[
        ("100R 50B", "[8]"),
        ("150R 50B", "[8]"),
        ("200R 50B", "[8]"),
        ("250R 50B", "[8]"),

        ("100R 50B", "[24, 8]"),
        ("150R 50B", "[24, 8]"),
        ("200R 50B", "[24, 8]"),
        ("250R 50B", "[24, 8]"),
    ],
    # y_ax = "Train Loss",
    x = "epochs", 
    # xlim = 300,
    xmin = 0,
    ylim = .7,
    ymin = .4,
    hide_legend = False
    # vbars = [(149, "lightgrey"), (169, "lightgrey")],
)

# %%
import importlib, utils
importlib.reload(utils)

# arch="[24, 48, 24, 8]"
selector = "med"
data = "vals"

utils.plot_seaborn(
    # title="ReLU vs BSpline, W&B_lr=0.001 BS_lr=0.0001 ctrl=3",
    model_paths=[
        ("RB", f"[8]_(0.001,0.0001,0.0001)_(200,50,0,50,0)_100", "vals", f"{selector}"),
        ("RB", f"[8]_(0.001,0.0001,0.0001)_(200,50,0,50,0)_100", "cr_vals", f"{selector}"),
        ("WB", "[8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),

        ("RB", f"[24, 8]_(0.001,0.0001,0.0001)_(200,50,0,50,0)_100", "vals", f"{selector}"),
        ("RB", f"[24, 8]_(0.001,0.0001,0.0001)_(200,50,0,50,0)_100", "cr_vals", f"{selector}"),
        ("WB", "[24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),

        ("RB", f"[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,50,0,50,0)_100", "vals", f"{selector}"),
        ("RB", f"[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,50,0,50,0)_100", "cr_vals", f"{selector}"),
        ("WB", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),

    ],
    aes=[
        ("200R 50B", "[8]"),
        ("250R", "[8]"),
        ("200WB", "[8]"),

        ("200R 50B", "[24, 8]"),
        ("250R", "[24, 8]"),
        ("200WB", "[24, 8]"),

        ("200R 50B", "[24, 48, 24, 8]"),
        ("250R", "[24, 48, 24, 8]"),
        ("200WB", "[24, 48, 24, 8]"),
    ],
    x = "time", 
    # xlim = 300,
    xmin = 0,
    ylim = .65,
    ymin = .35,
    hide_legend = False,
    # vbars = [(198, "lightgrey")],
)
# Out:
# Avg over last 5 epochs on 200R 50B,[8],med: 0.4832 in 290.98146971287105s
# Avg over last 5 epochs on 250R,[8],med: 0.4951 in 230.01153724752456s
# Avg over last 5 epochs on 200WB,[8],med: 0.4733 in 483.6654552899998s
# Avg over last 5 epochs on 200R 50B,[24, 8],med: 0.4375 in 391.2594189901959s
# Avg over last 5 epochs on 250R,[24, 8],med: 0.45255 in 274.05602569607817s
# Avg over last 5 epochs on 200WB,[24, 8],med: 0.44279999999999997 in 757.9136882699995s
# Avg over last 5 epochs on 200R 50B,[24, 48, 24, 8],med: 0.40945 in 591.4595634711541s
# Avg over last 5 epochs on 250R,[24, 48, 24, 8],med: 0.4316 in 377.8175238269232s
# Avg over last 5 epochs on 200WB,[24, 48, 24, 8],med: 0.4335 in 1298.4482278811884s

# %% [markdown]
# ### ReLU to BSpline to LSpline

# %%
import importlib, utils
importlib.reload(utils)

# arch="[24, 48, 24, 8]"
selector = "med"
data = "vals"

utils.plot_seaborn(
    # title="ReLU vs BSpline, W&B_lr=0.001 BS_lr=0.0001 ctrl=3",
    model_paths=[
        ("RBL", "[8]_(0.001,0.0001,0.0001)_(150,5,0,0,50)_100", "vals", f"{selector}"),
        ("RBL", "[24, 8]_(0.001,0.0001,0.0001)_(150,5,0,0,50)_100", "cr_vals", f"{selector}"),
        ("RBL", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(150,5,0,0,50)_100", "vals", f"{selector}"),
    ],
    aes=[
        ("150R 5B", "[8]"),
        ("150R 5B", "[24, 8]"),
        ("150R 5B", "[24, 48, 24, 8]"),
    ],
    # y_ax = "Train Loss",
    x = "epochs", 
    # xlim = 300,
    xmin = 0,
    ylim = .7,
    ymin = .4,
    hide_legend = False
    # vbars = [(149, "lightgrey"), (169, "lightgrey")],
)

# %% [markdown]
# ### ReLU to WBSpline to LSpline

# %% [markdown]
# ### ReLU to WBSpline to BSpline

# %%
import importlib, utils
importlib.reload(utils)

selector = "med"
data = "vals"

utils.plot_seaborn(
    # title="ReLU vs BSpline, W&B_lr=0.001 BS_lr=0.0001 ctrl=3",
    model_paths=[

        # ("R(WB)B", "[8]_(0.001,0.0001,0.0001)_(200,10,50,100,0)_100_bothfirst", "vals", f"{selector}"),
        ("R(WB)B", "[8]_(0.001,0.0001,0.0001)_(200,10,100,100,0)_100_bothfirst", "vals", f"{selector}"),
        ("R(WB)B", "[8]_(0.001,0.0001,0.0001)_(200,10,100,100,0)_100_bothfirst", "cr_vals", f"{selector}"),
        ("WB", "[8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),

        # ("R(WB)B", "[24, 8]_(0.001,0.0001,0.0001)_(200,10,50,100,0)_100_bothfirst", "vals", f"{selector}"),
        ("R(WB)B", "[24, 8]_(0.001,0.0001,0.0001)_(200,10,100,100,0)_100_bothfirst", "vals", f"{selector}"),
        ("R(WB)B", "[24, 8]_(0.001,0.0001,0.0001)_(200,10,100,100,0)_100_bothfirst", "cr_vals", f"{selector}"),
        ("WB", "[24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),

        # ("R(WB)B", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,10,50,100,0)_100_bothfirst", "vals", f"{selector}"),
        ("R(WB)B", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,10,100,100,0)_100_bothfirst", "vals", f"{selector}"),
        ("R(WB)B", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,10,100,100,0)_100_bothfirst", "cr_vals", f"{selector}"),
        ("WB", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),
    
    ],
    aes=[
        # ("200R 50WB 10B", "[8]"),
        ("200R 100WB 10B", "[8]"),
        ("300R", "[8]"),
        ("200 WB", "[8]"),

        # ("200R 50WB 10B", "[24, 8]"),
        ("200R 100WB 10B", "[24, 8]"),
        ("300R", "[24, 8]"),
        ("200 WB", "[24, 8]"),
        
        # ("200R 50WB 10B", "[24, 48, 24, 8]"),
        ("200R 100WB 10B", "[24, 48, 24, 8]"),
        ("300R", "[24, 48, 24, 8]"),
        ("200 WB", "[24, 48, 24, 8]"),

    ],
    x = "epochs", 
    xmin = 0,
    ylim = .6,
    ymin = .4,
    vbars = [(198, "lightgrey"), (298, "lightgrey")],
)
# Out:
# Avg over last 5 epochs on 200R 100WB 10B,[8],med: 0.4599 in 456.03065107619045s
# Avg over last 5 epochs on 300R,[8],med: 0.4909 in 273.01372960952364s
# Avg over last 5 epochs on 200 WB,[8],med: 0.4733 in 483.6654552899998s
# Avg over last 5 epochs on 200R 100WB 10B,[24, 8],med: 0.4217 in 615.6015985533979s
# Avg over last 5 epochs on 300R,[24, 8],med: 0.4505 in 313.0093640194175s
# Avg over last 5 epochs on 200 WB,[24, 8],med: 0.44279999999999997 in 757.9136882699995s
# Avg over last 5 epochs on 200R 100WB 10B,[24, 48, 24, 8],med: 0.4093 in 975.5455617156865s
# Avg over last 5 epochs on 300R,[24, 48, 24, 8],med: 0.4366 in 440.7041109313725s
# Avg over last 5 epochs on 200 WB,[24, 48, 24, 8],med: 0.4335 in 1298.4482278811884s

# %% [markdown]
# ### ReLU to BSpline to WBSpline

# %%
import importlib, utils
importlib.reload(utils)

selector = "med"
data = "trains"

utils.plot_seaborn(
    # title="ReLU vs BSpline, W&B_lr=0.001 BS_lr=0.0001 ctrl=3",
    model_paths=[

        # ("RB(WB)", "[8]_(0.001,0.0001,0.0001)_(200,10,50,100,0)_100", "vals", f"{selector}"),
        ("RB(WB)", "[8]_(0.001,0.0001,0.0001)_(200,10,100,100,0)_100", f"{data}", f"{selector}"),
        ("RB(WB)", "[8]_(0.001,0.0001,0.0001)_(200,10,100,100,0)_100", f"cr_{data}", f"{selector}"),
        # ("WB at 0.0001", "[8]_(0.001,0.0001,0.0001)_(['150R', '10B', '50WB'])_100_wbs_lr0.0001", f"{data}", f"{selector}"),
        # ("RB(WB)", "[8]_(0.001,0.0001,0.0001)_(200,10,100,100,0)_100", f"cr_{data}", f"{selector}"),
        # ("WB", "[8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),

        # ("RB(WB)", "[24, 8]_(0.001,0.0001,0.0001)_(200,10,50,100,0)_100", "vals", f"{selector}"),
        ("RB(WB)", "[24, 8]_(0.001,0.0001,0.0001)_(200,10,100,100,0)_100", f"{data}", f"{selector}"),
        ("RB(WB)", "[24, 8]_(0.001,0.0001,0.0001)_(200,10,100,100,0)_100", f"cr_{data}", f"{selector}"),
        # ("WB at 0.0001", "[24, 8]_(0.001,0.0001,0.0001)_(['150R', '10B', '50WB'])_100_wbs_lr0.0001", f"{data}", f"{selector}"),
        # ("RB(WB)", "[24, 8]_(0.001,0.0001,0.0001)_(200,10,100,100,0)_100", f"cr_{data}", f"{selector}"),
        # ("WB", "[24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),


        # ("WB at 0.0001", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(['150R', '10B', '50WB'])_100_wbs_lr0.0001", f"{data}", f"{selector}"),
        # ("RB(WB)", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,10,100,100,0)_100", f"cr_{data}", f"{selector}"),
        # ("WB", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),

        # ("RB(WB)", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,10,50,100,0)_100", "vals", f"{selector}"),
        ("RB(WB)", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,10,100,100,0)_100", f"{data}", f"{selector}"),
        ("RB(WB)", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,10,100,100,0)_100", f"cr_{data}", f"{selector}"),
        # ("WB at 0.0001", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,10,100,100,0)_100", f"{data}", f"{selector}"),
        # ("RB(WB)", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,10,100,100,0)_100", f"cr_{data}", f"{selector}"),
        # ("WB", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(0,0,200,0,0)_100", "vals", f"{selector}"),
    ],
    aes=[
        # ("200R 10B 50WB", "[8]"),
        ("200R 10B 100WB", "[8]"),
        # ("150R 10B 50WB", "[8]"),
        ("300R", "[8]"),
        # ("200 WB", "[8]"),

        # ("200R 10B 50WB", "[24, 8]"),
        ("200R 10B 100WB", "[24, 8]"),
        # ("150R 10B 50WB", "[24, 8]"),
        ("300R", "[24, 8]"),
        # ("200 WB", "[24, 8]"),

        # ("200R 10B 50WB", "[24, 48, 24, 8]"),
        ("200R 10B 100WB", "[24, 48, 24, 8]"),
        # ("150R 10B 50WB", "[24, 48, 24, 8]"),
        ("300R", "[24, 48, 24, 8]"),
        # ("200 WB", "[24, 48, 24, 8]"),
    ],
    x = "epochs", 
    ylim = .6,
    ymin = .35,
    hide_legend = False,
    vbars = [(198, "lightgrey"), (208, "lightgrey")],
)
# Out:
# Avg over last 5 epochs on 200R 10B 100WB,[8],med: 0.4780935659253782 in 458.94435155445564s
# Avg over last 5 epochs on 300R,[8],med: 0.4909324749231481 in 275.23622375247527s
# Avg over last 5 epochs on 200R 10B 100WB,[24, 8],med: 0.4349031840343618 in 651.2133354857141s
# Avg over last 5 epochs on 300R,[24, 8],med: 0.4418833454857664 in 331.38859s
# Avg over last 5 epochs on 200R 10B 100WB,[24, 48, 24, 8],med: 0.400859585297398 in 1027.3298555294116s
# Avg over last 5 epochs on 300R,[24, 48, 24, 8],med: 0.40288231109088046 in 458.02433733333334s

# %%
import importlib, utils
importlib.reload(utils)

selector = "med"
data = "vals"

utils.plot_seaborn(
    model_paths=[
        ("WB at 0.0001", "[8]_(0.001,0.0001,0.0001)_(['150R', '10B', '50WB'])_100_wbs_lr0.0001", "vals", f"{selector}"),
        ("WB at 0.0001", "[8]_(0.001,0.0001,0.0001)_(['150R', '10B', '50WB'])_100_wbs_lr0.0001", "cr_vals", f"{selector}"),
        ("WB at 0.0001", "[24, 8]_(0.001,0.0001,0.0001)_(['150R', '10B', '50WB'])_100_wbs_lr0.0001", "vals", f"{selector}"),
        ("WB at 0.0001", "[24, 8]_(0.001,0.0001,0.0001)_(['150R', '10B', '50WB'])_100_wbs_lr0.0001", "cr_vals", f"{selector}"),
        ("WB at 0.0001", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(['150R', '10B', '50WB'])_100_wbs_lr0.0001", "vals", f"{selector}"),
        ("WB at 0.0001", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(['150R', '10B', '50WB'])_100_wbs_lr0.0001", "cr_vals", f"{selector}"),
    ],
    aes=[
        ("150R 10B 50WB", "[8]"),
        ("250R", "[8]"),

        ("150R 10B 50WB", "[24, 8]"),
        ("250R", "[24, 8]"),
        
        ("150R 10B 50WB", "[24, 48, 24, 8]"),
        ("250R", "[24, 48, 24, 8]"),
    ],
    x = "epochs", 
    ylim = .6,
    ymin = .35,
    vbars = [(148, "lightgrey"), (158, "lightgrey")],
)
# Out:
# Avg over last 5 epochs on 150R 10B 50WB,[8],med: 0.4733 in 275.83863869s
# Avg over last 5 epochs on 250R,[8],med: 0.4941 in 222.05082806999985s
# Avg over last 5 epochs on 150R 10B 50WB,[24, 8],med: 0.43735 in 378.6646506600001s
# Avg over last 5 epochs on 250R,[24, 8],med: 0.45425 in 264.98103247999995s
# Avg over last 5 epochs on 150R 10B 50WB,[24, 48, 24, 8],med: 0.4151 in 600.2982313168316s
# Avg over last 5 epochs on 250R,[24, 48, 24, 8],med: 0.42965 in 376.3284821599998s

# %% [markdown]
# ### ReLU to WBSpline to LSpline

# %%
import importlib, utils
importlib.reload(utils)

selector = "med"
data = "vals"

utils.plot_seaborn(
    # title="ReLU vs BSpline, W&B_lr=0.001 BS_lr=0.0001 ctrl=3",
    model_paths=[

        # 200 relu, 50 both, 200 comp, 100 lspline
        ("R(WB)L", "[8]_(0.001,0.0001,0.0001)_(200,0,50,200,100)_100", "vals", f"{selector}"),
        ("R(WB)L", "[8]_(0.001,0.0001,0.0001)_(200,0,50,200,100)_100", "cr_vals", f"{selector}"),

        ("R(WB)L", "[24, 8]_(0.001,0.0001,0.0001)_(200,0,50,200,100)_100", "vals", f"{selector}"),
        ("R(WB)L", "[24, 8]_(0.001,0.0001,0.0001)_(200,0,50,200,100)_100", "cr_vals", f"{selector}"),
        
        ("R(WB)L", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,0,50,200,100)_100", "vals", f"{selector}"),
        ("R(WB)L", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,0,50,200,100)_100", "cr_vals", f"{selector}"),
    ],
    aes=[
        ("200R 50WB 100L", "[8]"),
        ("400R", "[8]"),

        ("200R 50WB 100L", "[24, 8]"),
        ("400R", "[24, 8]"),

        ("200R 50WB 100L", "[24, 48, 24, 8]"),
        ("400R", "[24, 48, 24, 8]"),
    ],
    x = "epochs", 
    # xlim = 300,
    xmin = 0,
    ylim = .55,
    ymin = .35,
    hide_legend = False,
    # cutoff = 260-1,
    vbars = [(198, "lightgrey"), (248, "lightgrey")],
)
# Out:
# Avg over last 5 epochs on 200R 50WB 100L,[8],med: 0.4502 in 430.7170123099995s
# Avg over last 5 epochs on 400R,[8],med: 0.4818 in 357.80393761999954s
# Avg over last 5 epochs on 200R 50WB 100L,[24, 8],med: 0.41390000000000005 in 598.6454383490567s
# Avg over last 5 epochs on 400R,[24, 8],med: 0.4424 in 439.55451165714294s
# Avg over last 5 epochs on 200R 50WB 100L,[24, 48, 24, 8],med: 0.4161 in 923.0520392211541s
# Avg over last 5 epochs on 400R,[24, 48, 24, 8],med: 0.4281 in 612.4998617307695s

# %% [markdown]
# ### ReLU to BSpline to LSpline

# %%
import importlib, utils
importlib.reload(utils)

selector = "med"
data = "vals"

utils.plot_seaborn(
    # title="ReLU vs BSpline, W&B_lr=0.001 BS_lr=0.0001 ctrl=3",
    model_paths=[

        ("RBL", "[8]_(0.001,0.0001,0.0001)_(200,10,0,150,100)_100", "vals", f"{selector}"),
        ("RBL", "[8]_(0.001,0.0001,0.0001)_(200,10,0,150,100)_100", "cr_vals", f"{selector}"),

        ("RBL", "[24, 8]_(0.001,0.0001,0.0001)_(200,10,0,150,100)_100", "vals", f"{selector}"),
        ("RBL", "[24, 8]_(0.001,0.0001,0.0001)_(200,10,0,150,100)_100", "cr_vals", f"{selector}"),

        ("RBL", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,10,0,150,100)_100", "vals", f"{selector}"),
        ("RBL", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,10,0,150,100)_100", "cr_vals", f"{selector}"),

    ],
    aes=[
        ("200R 10B 100L", "[8]"),
        ("350R", "[8]"),

        ("200R 10B 100L", "[24, 8]"),
        ("350R", "[24, 8]"),

        ("200R 10B 100L", "[24, 48, 24, 8]"),
        ("350R", "[24, 48, 24, 8]"),
    ],
    # y_ax = "Train Loss",
    x = "epochs", 
    # xlim = 300,
    xmin = 0,
    ylim = .55,
    ymin = .35,
    hide_legend = False,
    # cutoff = 260-1,
    vbars = [(198, "lightgrey"), (208, "lightgrey")],
)
# Out:
# Avg over last 5 epochs on 200R 10B 100L,[8],med: 0.4606 in 330.39935934653454s
# Avg over last 5 epochs on 350R,[8],med: 0.4875 in 315.52793913861365s
# Avg over last 5 epochs on 200R 10B 100L,[24, 8],med: 0.427 in 439.57349047572836s
# Avg over last 5 epochs on 350R,[24, 8],med: 0.4448 in 385.82155007766977s
# Avg over last 5 epochs on 200R 10B 100L,[24, 48, 24, 8],med: 0.4137 in 654.1745260485437s
# Avg over last 5 epochs on 350R,[24, 48, 24, 8],med: 0.4328 in 533.7346104757279s

# %% [markdown]
# ### ReLU to WBSpline to BSpline to LSpline

# %% [markdown]
# ### Small Models

# %%
import importlib, utils
importlib.reload(utils)

selector = "med"
data = "vals"

utils.plot_seaborn(
    model_paths=[
        # ("", "", "", ""),
        ("small models", "[1]_(0.001,0.0001,0.0001)_(['200R', '50B'])_100", "vals", "med"),
        ("small models", "[2]_(0.001,0.0001,0.0001)_(['200R', '50B'])_100", "vals", "med"),
        ("small models", "[4]_(0.001,0.0001,0.0001)_(['200R', '50B'])_100", "vals", "med"),
        ("small models", "[8]_(0.001,0.0001,0.0001)_(['200R', '50B'])_100", "vals", "med"),

        ("small models", "[1]_(0.001,0.0001,0.0001)_(['200R', '50B'])_100", "cr_vals", "med"),
        ("small models", "[2]_(0.001,0.0001,0.0001)_(['200R', '50B'])_100", "cr_vals", "med"),
        ("small models", "[4]_(0.001,0.0001,0.0001)_(['200R', '50B'])_100", "cr_vals", "med"),
        ("small models", "[8]_(0.001,0.0001,0.0001)_(['200R', '50B'])_100", "cr_vals", "med"),
    ],
    aes=[
        ("200R 50B", "[1]"),
        ("200R 50B", "[2]"),
        ("200R 50B", "[4]"),
        ("200R 50B", "[8]"),

        ("250R", "[1]"),
        ("250R", "[2]"),
        ("250R", "[4]"),
        ("250R", "[8]"),
    ],
    x = "epochs",
    ylim = .8,
    ymin = .4,
)

# %%
import importlib, utils
importlib.reload(utils)

selector = "med"
data = "vals"

utils.plot_seaborn(
    model_paths=[
        ("small models", "[1]_(0.001,0.0001,0.0001)_(200,10,100,250,100)_100", "vals", "med"),
        ("small models", "[2]_(0.001,0.0001,0.0001)_(200,10,100,250,100)_100", "vals", "med"),
        ("small models", "[6]_(0.001,0.0001,0.0001)_(200,10,100,250,100)_100", "vals", "med"),
    ],
    aes=[
        ("200R 10B 100WB 100L", "[1]"),
        ("200R 10B 100WB 100L", "[2]"),
        ("200R 10B 100WB 100L", "[6]"),
    ],
    x = "epochs",
    ylim = 2,
    ymin = .4,
)

# %%
import importlib, utils
importlib.reload(utils)

selector = "med"
data = "vals"

utils.plot_seaborn(
    model_paths=[
        ("", "", "vals", "med"),
    ],
    aes=[
        ("valsL", "[1]"),
    ],
    x = "epochs",
    ylim = 2,
    ymin = .4,
)

# %% [markdown]
# ### ReLU to BSpline to FBSpline

# %%
import importlib, utils
importlib.reload(utils)

selector = "med"
data = "vals"

utils.plot_seaborn(
    model_paths=[
        ("RB(FB)", f"[8]_(0.001,0.0001,0.0001)_(['150R', '10B', '50FB'])_100", f"{data}", f"{selector}"),
        ("RB(FB)", f"[8]_(0.001,0.0001,0.0001)_(['150R', '10B', '50FB'])_100", f"cr_vals", f"{selector}"),

        ("RB(FB)", f"[24, 8]_(0.001,0.0001,0.0001)_(['150R', '10B', '50FB'])_100", f"{data}", f"{selector}"),
        ("RB(FB)", f"[24, 8]_(0.001,0.0001,0.0001)_(['150R', '10B', '50FB'])_100", f"cr_vals", f"{selector}"),

        ("RB(FB)", f"[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(['150R', '10B', '50FB'])_100", f"{data}", f"{selector}"),
        ("RB(FB)", f"[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(['150R', '10B', '50FB'])_100", f"cr_vals", f"{selector}"),
    ],
    aes=[
        ("150R 10B 50FB", "[8]"),
        ("250R", "[8]"),
        ("150R 10B 50FB", "[24, 8]"),
        ("250R", "[24, 8]"),
        ("150R 10B 50FB", "[24, 48, 24, 8]"),
        ("250R", "[24, 48, 24, 8]"),
    ],
    x = "epochs", 
    ylim = .65,
    ymin = .35,
    vbars = [(148, "lightgrey"), (158, "lightgrey")],
)
# Out:
# Avg over last 5 epochs on 150R 10B 50FB,[8],med: 0.4767 in 219.95638737000004s
# Avg over last 5 epochs on 250R,[8],med: 0.49745 in 219.66980524000024s
# Avg over last 5 epochs on 150R 10B 50FB,[24, 8],med: 0.4383 in 293.48357174285724s
# Avg over last 5 epochs on 250R,[24, 8],med: 0.4563 in 268.5931090095237s
# Avg over last 5 epochs on 150R 10B 50FB,[24, 48, 24, 8],med: 0.4126 in 442.80400252941183s
# Avg over last 5 epochs on 250R,[24, 48, 24, 8],med: 0.4315 in 375.17784372549016s

# %% [markdown]
# ### WBSpline to FBSpline

# %%
import importlib, utils
importlib.reload(utils)

selector = "med"
data = "vals"

utils.plot_seaborn(
    model_paths=[ 
        ("WB to FB", "[8]_(0.001,0.0001,0.0001)_(['150WB', '50FB'])_20", "vals", "med"),
        ("WB to FB", "[24, 8]_(0.001,0.0001,0.0001)_(['150WB', '50FB'])_20", "vals", "med"),
        ("WB to FB", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(['150WB', '50FB'])_20", "vals", "med"),

        # ("RB", "[8]_(0.001,0.0001,0.0001)_(['150R', '10B'])_100", "vals", "med"),
        # ("RB", "[24, 8]_(0.001,0.0001,0.0001)_(['150R', '10B'])_100", "vals", "med"),
        # ("RB", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(['150R', '10B'])_100", "vals", "med"),

        ("R", "[8]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", "med"),
        ("R", "[24, 8]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", "med"),
        ("R", "[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", "med"),

    ],
    aes=[
        ("150WB 50FB", "[8]"),
        ("150WB 50FB", "[24, 8]"),
        ("150WB 50FB", "[24, 48, 24, 8]"),
        
        # ("150R 10B", "[8]"),
        # ("150R 10B", "[24, 8]"),
        # ("150R 10B", "[24, 48, 24, 8]"),

        ("200R", "[8]"),
        ("200R", "[24, 8]"),
        ("200R", "[24, 48, 24, 8]"),
    ],
    x = "epochs",
    ylim = .65,
    ymin = .35,
    vbars = [(148, "lightgrey")],
)
# Out:
# Avg over last 5 epochs on 150WB 50FB,[8],med: 0.46495 in 438.2827637999999s
# Avg over last 5 epochs on 150WB 50FB,[24, 8],med: 0.41485 in 668.4021354500001s
# Avg over last 5 epochs on 150WB 50FB,[24, 48, 24, 8],med: 0.40249999999999997 in 1135.5376266000005s
# Avg over last 5 epochs on 200R,[8],med: 0.4868 in 191.56679745544545s
# Avg over last 5 epochs on 200R,[24, 8],med: 0.4644 in 230.9543103960394s
# Avg over last 5 epochs on 200R,[24, 48, 24, 8],med: 0.439 in 308.6244620666665s

# %% [markdown]
# ### Cycling

# %%
import importlib, utils
importlib.reload(utils)

selector = "med"
data = "vals"

utils.plot_seaborn(
    model_paths=[
        ("cycling", f"[8]_(0.001,0.0001,0.0001)_(['150R', '10B', '50FB', '10B', '50FB', '10B', '50FB', '10B', '50FB'])_100", f"{data}", f"{selector}"),
        ("cycling", f"[8]_(0.001,0.0001,0.0001)_(['150R', '10B', '50FB', '10B', '50FB', '10B', '50FB', '10B', '50FB'])_100", f"cr_{data}", f"{selector}"),

        ("cycling", f"[24, 8]_(0.001,0.0001,0.0001)_(['150R', '10B', '50FB', '10B', '50FB', '10B', '50FB', '10B', '50FB'])_100", f"{data}", f"{selector}"),
        ("cycling", f"[24, 8]_(0.001,0.0001,0.0001)_(['150R', '10B', '50FB', '10B', '50FB', '10B', '50FB', '10B', '50FB'])_100", f"cr_{data}", f"{selector}"),

        ("cycling", f"[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(['150R', '10B', '50FB', '10B', '50FB', '10B', '50FB', '10B', '50FB'])_100", f"{data}", f"{selector}"),
        ("cycling", f"[24, 48, 24, 8]_(0.001,0.0001,0.0001)_(['150R', '10B', '50FB', '10B', '50FB', '10B', '50FB', '10B', '50FB'])_100", f"cr_{data}", f"{selector}"),
    ],
    aes=[
        ("150R (10B, 50FB)x4", "[8]"),
        ("250R", "[8]"),

        ("(10B, 50FB)x4", "[24, 8]"),
        ("250R", "[24, 8]"),

        ("(10B, 50FB)x4", "[24, 48, 24, 8]"),
        ("250R", "[24, 48, 24, 8]"),
    ],
    x = "epochs", 
    ylim = .65,
    ymin = .35,
    # vbars = [(148, "lightgrey"), (158, "lightgrey")],
)
# Out:
# Avg over last 5 epochs on Cycle,[8],med: 0.4616 in 490.74933114285716s
# Avg over last 5 epochs on ReLU,[8],med: 0.4934 in 221.90608380000003s
# Avg over last 5 epochs on Cycle,[24, 8],med: 0.4269 in 710.1161611862744s
# Avg over last 5 epochs on ReLU,[24, 8],med: 0.45225000000000004 in 275.74038616666684s
# Avg over last 5 epochs on Cycle,[24, 48, 24, 8],med: 0.41565 in 1091.8135268921565s
# Avg over last 5 epochs on ReLU,[24, 48, 24, 8],med: 0.431 in 370.0571819313726s

# %% [markdown]
# ### LR Scheduling after Switch

# %%
import importlib, utils
importlib.reload(utils)

selector = "best"
data = "vals"

utils.plot_seaborn(
    model_paths=[ 
        ("WBS_lrsched after transfer", "[8]_(0.001,0.0001,0.0001,0.9,5)_(['150R', '150WB'])_100_wbs_lrsched", "vals", "med"),
        ("WBS_lrsched after transfer", "[8]_(0.001,0.0001,0.0001,0.9,5)_(['150R', '150WB'])_100_wbs_lrsched", "cr_vals", "med"),
        ("WBS_lrsched after transfer", "[24, 8]_(0.001,0.0001,0.0001,0.9,5)_(['150R', '150WB'])_100_wbs_lrsched", "vals", "med"),
        ("WBS_lrsched after transfer", "[24, 8]_(0.001,0.0001,0.0001,0.9,5)_(['150R', '150WB'])_100_wbs_lrsched", "cr_vals", "med"),
        ("WBS_lrsched after transfer", "[24, 48, 24, 8]_(0.001,0.0001,0.0001,0.9,5)_(['150R', '150WB'])_100_wbs_lrsched", "vals", "med"),
        ("WBS_lrsched after transfer", "[24, 48, 24, 8]_(0.001,0.0001,0.0001,0.9,5)_(['150R', '150WB'])_100_wbs_lrsched", "cr_vals", "med"),

    ],
    aes=[
        ("150R 150WB (lrs)", "[8]"),
        ("300R", "[8]"),
        ("150R 150WB (lrs)", "[24, 8]"),
        ("300R", "[24, 8]"),
        ("150R 150WB (lrs)", "[24, 48, 24, 8]"),
        ("300R", "[24, 48, 24, 8]"),
    ],
    x = "epochs",
    ylim = .65,
    ymin = .35,
    vbars = [(148, "lightgrey")],
)
# Out:
# Avg over last 5 epochs on 150R 150WB (lrs),[8],med: 0.4538 in 500.5512458921571s
# Avg over last 5 epochs on 300R,[8],med: 0.49025 in 262.84278111764706s
# Avg over last 5 epochs on 150R 150WB (lrs),[24, 8],med: 0.41625 in 729.6345447641514s
# Avg over last 5 epochs on 300R,[24, 8],med: 0.45225 in 319.8894721792453s
# Avg over last 5 epochs on 150R 150WB (lrs),[24, 48, 24, 8],med: 0.4099 in 1189.906805306931s
# Avg over last 5 epochs on 300R,[24, 48, 24, 8],med: 0.4344 in 450.14778598019797s

# %% [markdown]
# ### Performance comparison of best models

# %%
import importlib, utils
importlib.reload(utils)

selector = "med"
data = "vals"

model = "[24, 48, 24, 8]"

utils.plot_seaborn(
    model_paths=[
        ("R", f"{model}_(0.001,0.0001,0.0001)_(200,0,0,0,0)_100", "vals", "med"),
        ("RB", f"{model}_(0.001,0.0001,0.0001)_(200,50,0,50,0)_100", "vals", f"{selector}"),
        ("R(WB)B", f"{model}_(0.001,0.0001,0.0001)_(200,10,100,100,0)_100_bothfirst", "vals", f"{selector}"),
        ("WBS_lrsched after transfer", f"{model}_(0.001,0.0001,0.0001,0.9,5)_(['150R', '150WB'])_100_wbs_lrsched", "vals", "med"),
        ("WB to FB", f"{model}_(0.001,0.0001,0.0001)_(['150WB', '50FB'])_100", "vals", "med"),

    ],
    aes=[
        ("200R", f"{model}"),
        ("200R 50B", f"{model}"),
        ("200R 100WB 10B", f"{model}"),
        ("150R 150WB_lrs", f"{model}"),
        ("150WB 50FB", f"{model}"),        
    ],
    x = "time",
    ylim = .55,
    ymin = .35,
    # vbars = [(148, "lightgrey")],
)
# Out:
# Avg over last 5 epochs on 200R,[24, 48, 24, 8],med: 0.439 in 308.6244620666665s
# Avg over last 5 epochs on 200R 50B,[24, 48, 24, 8],med: 0.40945 in 591.4595634711541s
# Avg over last 5 epochs on 200R 100WB 10B,[24, 48, 24, 8],med: 0.4093 in 975.5455617156865s
# Avg over last 5 epochs on 150R 150WB_lrs,[24, 48, 24, 8],med: 0.4099 in 1189.906805306931s
# Avg over last 5 epochs on 150WB 50FB,[24, 48, 24, 8],med: 0.40355 in 1134.9287584900005s

# %%
import json, torch

model="[24, 48, 24, 8]"
# file = f"RB/{model}_(0.001,0.0001,0.0001)_(['150R', '10B'])_100"
file = f"{model}_(0.001,0.0001,0.0001)_(['200R', '100WB', '10B'])_100"
# file = f"WBS_lrsched after transfer/{model}_(0.001,0.0001,0.0001,0.9,5)_(['150R', '150WB'])_100_wbs_lrsched"
# file = f"WB to FB/{model}_(0.001,0.0001,0.0001)_(['150WB', '50FB'])_100"


with open(f'saved/{file}.json', 'r') as file:
    model_data = json.load(file)

print(torch.mean(torch.tensor(model_data["zeroed"], dtype=torch.float32), dim=0))
# Out:
# tensor([3.3200, 0.7100])

# %%
import importlib, utils
importlib.reload(utils)

selector = "med"
data = "vals"

utils.plot_seaborn(
    model_paths=[ 
        # ("", "[1]_(0.001,0.0001,0.0001)_(['200R', '50B'])_100", "vals", "med"),
        # ("", "[2]_(0.001,0.0001,0.0001)_(['200R', '50B'])_100", "vals", "med"),
        ("", "[4]_(0.001,0.0001,0.0001)_(['200R', '50B'])_100", "vals", "med"),

        # ("small models", "[1]_(0.001,0.0001,0.0001)_(['200R', '50B'])_100", "vals", "med"),
        # ("small models", "[2]_(0.001,0.0001,0.0001)_(['200R', '50B'])_100", "vals", "med"),
        ("small models", "[4]_(0.001,0.0001,0.0001)_(['200R', '50B'])_100", "vals", "med"),

        # ("", "", "vals", "med"),

    ],
    aes=[
        ("200R 50B", "[1]"),
        ("200R 50B", "[2]"),
        ("200R 50B", "[4]"),
    ],
    x = "epochs",
    ylim = 1,
    # ymin = .35,
    vbars = [(148, "lightgrey")],
)
# Out:
# Avg over last 5 epochs on 200R 50B,[1],med: 0.50125 in 272.36519258653834s
# Avg over last 5 epochs on 200R 50B,[2],med: 0.5093 in 268.52151691891885s
